# %%
import pandas as pd
import os
os.chdir('/Users/markjos/projects/malachor5')
import numpy as np
from typing import Literal
from tqdm import tqdm
tqdm.pandas()
from glob import glob
import math
from string import punctuation
from random import shuffle
import shutil

import sys
sys.path.append('scripts')
from eval import get_word_language
from longform import load_and_resample
import torchaudio
import torch
import json

from transformers import WhisperTokenizer
from datasets import load_dataset

# %% [markdown]
# # Steps to generate dataset
# - Run text proc (use existing code)
#   - Add 'valid' col and set excluded rows to False (both malformed English and autogen Tira)
# - Load Tira CS idcs & map to ASR index
#   - For each ASR index, check if an unvalid record exists within its time domain
#   - `is_punct==True` should not be excluded here, under the assumption that it reflects silence
#   - Create new dataset only containing valid records, save and upload

# %%
snippet_csv = 'data/elicitation-wavs/autotranscribed/metadata.csv'
df = pd.read_csv(snippet_csv, keep_default_na=False)
df['filestem']=df['wav_source'].apply(
    lambda x: os.path.basename(os.path.splitext(x)[0])
)
print(f"{df.shape=}")
df.head()
# Out:
# df.shape=(109393, 10)
#    Unnamed: 0 wav_path tier_name  start    end  \
# 0           0                asr     30   1414
# 1           1                asr   2106   4755
# 2           2                asr   6240   8502
# 3           3                asr   8535   8569
# 4           4                asr   8721  11269
#
#                          transcription  \
# 0                 Hello, hello, hello.
# 1   Hello, hello, hello, hello, hello.
# 2             Hello, hello. This shit.
# 3                                  ...
# 4                 Hello. Hello. Hello.
#
#                                             eaf_path  \
# 0  /home/AD/mjsimmons/datasets/elicitation-wavs/a...
# 1  /home/AD/mjsimmons/datasets/elicitation-wavs/a...
# 2  /home/AD/mjsimmons/datasets/elicitation-wavs/a...
# 3  /home/AD/mjsimmons/datasets/elicitation-wavs/a...
# 4  /home/AD/mjsimmons/datasets/elicitation-wavs/a...
#
#                                           wav_source sli_pred    filestem
# 0  /home/AD/mjsimmons/datasets/elicitation-wavs/m...      ENG  HH01082021
# 1  /home/AD/mjsimmons/datasets/elicitation-wavs/m...      ENG  HH01082021
# 2  /home/AD/mjsimmons/datasets/elicitation-wavs/m...      ENG  HH01082021
# 3  /home/AD/mjsimmons/datasets/elicitation-wavs/m...      ENG  HH01082021
# 4  /home/AD/mjsimmons/datasets/elicitation-wavs/m...      ENG  HH01082021

# %%
balance_df = pd.read_csv('/Users/markjos/projects/malachor5/notebooks/longform_dataset/balance_df.csv', index_col='index')
balance_df.head()
# Out:
#        Unnamed: 0 tier_name    start      end          transcription  \
# index
# 0               0       asr     30.0   1414.0      hello hello hello
# 1               1       asr   6240.0   8502.0  hello hello this shit
# 2               2       asr  11387.0  13244.0          i do not know
# 3               3       asr  13649.0  13986.0                   yeah
# 4               4       asr  26625.0  27064.0              thank you
#
#                                                 eaf_path  \
# index
# 0      /home/AD/mjsimmons/datasets/elicitation-wavs/a...
# 1      /home/AD/mjsimmons/datasets/elicitation-wavs/a...
# 2      /home/AD/mjsimmons/datasets/elicitation-wavs/a...
# 3      /home/AD/mjsimmons/datasets/elicitation-wavs/a...
# 4      /home/AD/mjsimmons/datasets/elicitation-wavs/a...
#
#                                               wav_source sli_pred  asr_index  \
# index
# 0      /home/AD/mjsimmons/datasets/elicitation-wavs/m...      ENG        NaN
# 1      /home/AD/mjsimmons/datasets/elicitation-wavs/m...      ENG        NaN
# 2      /home/AD/mjsimmons/datasets/elicitation-wavs/m...      ENG        NaN
# 3      /home/AD/mjsimmons/datasets/elicitation-wavs/m...      ENG        NaN
# 4      /home/AD/mjsimmons/datasets/elicitation-wavs/m...      ENG        NaN
#
#       split    filestem  duration lang_balanced_dataset  \
# index
# 0       NaN  HH01082021    1384.0                   NaN
# 1       NaN  HH01082021    2262.0                   NaN
# 2       NaN  HH01082021    1857.0                   NaN
# 3       NaN  HH01082021     337.0                   NaN
# 4       NaN  HH01082021     439.0                   NaN
#
#                                    label_path  \
# index
# 0      data/elicitation-wavs/wav/labels/0.txt
# 1      data/elicitation-wavs/wav/labels/1.txt
# 2      data/elicitation-wavs/wav/labels/2.txt
# 3      data/elicitation-wavs/wav/labels/3.txt
# 4      data/elicitation-wavs/wav/labels/4.txt
#
#                                    clip_name
# index
# 0      data/elicitation-wavs/wav/clips/0.wav
# 1      data/elicitation-wavs/wav/clips/1.wav
# 2      data/elicitation-wavs/wav/clips/2.wav
# 3      data/elicitation-wavs/wav/clips/3.wav
# 4      data/elicitation-wavs/wav/clips/4.wav

# %%
tira_cs_idcs_path = '/Users/markjos/projects/malachor5/notebooks/longform_dataset/data/tira_cs_indices.txt'
with open(tira_cs_idcs_path) as f:
    tira_cs_idcs = [int(line.strip()) for line in f.readlines()]
tira_cs_idcs
# Out:
# [47327,
#  47328,
#  47330,
#  47334,
#  47335,
#  47339,
#  47342,
#  47343,
#  47344,
#  47345,
#  47352,
#  47353,
#  47357,
#  47358,
#  47364,
#  47366,
#  47375,
#  47376,
#  47377,
#  47378,
#  47381,
#  47386,
#  47389,
#  47391,
#  47392,
#  47395,
#  47398,
#  47399,
#  47402,
#  47403,
#  47410,
#  47411,
#  47413,
#  47424,
#  47425,
#  47428,
#  47442,
#  47445,
#  47446,
#  47447,
#  47448,
#  47457,
#  47460,
#  47473,
#  47477,
#  47480,
#  47492,
#  47494,
#  47495,
#  47499,
#  47500,
#  47506,
#  47509,
#  47510,
#  47511,
#  47515,
#  47520,
#  47522,
#  47525,
#  47530,
#  47532,
#  47533,
#  47539,
#  47540,
#  47542,
#  47549,
#  47552,
#  47553,
#  47554,
#  47555,
#  47559,
#  47560,
#  47565,
#  47569,
#  47571,
#  47576,
#  47580,
#  47583,
#  47585,
#  47588,
#  47601,
#  47608,
#  47610,
#  47614,
#  47617,
#  47618,
#  47623,
#  47630,
#  47631,
#  47634,
#  47635,
#  47636,
#  47640,
#  47641,
#  47644,
#  47647,
#  47648,
#  47650,
#  47655,
#  47658,
#  47660,
#  47663,
#  47664,
#  47666,
#  47668,
#  47675,
#  47677,
#  47678,
#  47682,
#  47683,
#  47687,
#  47688,
#  47689,
#  47691,
#  47696,
#  47697,
#  47699,
#  47702,
#  47707,
#  47710,
#  47718,
#  47724,
#  47731,
#  47736,
#  47744,
#  47745,
#  47746,
#  47748,
#  47750,
#  47753,
#  47760,
#  47762,
#  47764,
#  47766,
#  47767,
#  47769,
#  47770,
#  47771,
#  47772,
#  47775,
#  47781,
#  47782,
#  47784,
#  47785,
#  47786,
#  47788,
#  47789,
#  47791,
#  47792,
#  47797,
#  47815,
#  47818,
#  47819,
#  47820,
#  47821,
#  47823,
#  47826,
#  47832,
#  47833,
#  47836,
#  47837,
#  47838,
#  47840,
#  47843,
#  47847,
#  47850,
#  47853,
#  47854,
#  47856,
#  47858,
#  47861,
#  47869,
#  47870,
#  47871,
#  47880,
#  47881,
#  47886,
#  47890,
#  47894,
#  47896,
#  47902,
#  47905,
#  47909,
#  47912,
#  47913,
#  47916,
#  47923,
#  47925,
#  47926,
#  47927,
#  47928,
#  47929,
#  47933,
#  47936,
#  47937,
#  47938,
#  47939,
#  47940,
#  47941,
#  47947,
#  47948,
#  47953,
#  47958,
#  47959,
#  47965,
#  47966,
#  47967,
#  47969,
#  47972,
#  47978,
#  47979,
#  47982,
#  47983,
#  47985,
#  47986,
#  47989,
#  47993,
#  47999,
#  48000,
#  48003,
#  48004,
#  48009,
#  48010,
#  48014,
#  48015,
#  48017,
#  48018,
#  48020,
#  48023,
#  48026,
#  48027,
#  48030,
#  48033,
#  48037,
#  48038,
#  48039,
#  48040,
#  48041,
#  48046,
#  48047,
#  48051,
#  48057,
#  48068,
#  48069,
#  48074,
#  48075,
#  48077,
#  48082,
#  48085,
#  48086,
#  48088,
#  48090,
#  48099,
#  48100,
#  48102,
#  48106,
#  48113,
#  48116,
#  48117,
#  48119,
#  48121,
#  48123,
#  48125,
#  48127,
#  48131,
#  48134,
#  48136,
#  48141,
#  48143,
#  48144,
#  48155,
#  48156,
#  48164,
#  48166,
#  48167,
#  48168,
#  48176,
#  48177,
#  48179,
#  48180,
#  48188,
#  48192,
#  48195,
#  48198,
#  48200,
#  48201,
#  48205,
#  48206,
#  48208,
#  48211,
#  48213,
#  48214,
#  48224,
#  48227,
#  48229,
#  48232,
#  48234,
#  48236,
#  48240,
#  48256,
#  48258,
#  48259,
#  48263,
#  48264,
#  48269,
#  48270,
#  48274,
#  48280,
#  48281,
#  48282,
#  48292,
#  48293,
#  48297,
#  48298,
#  48299,
#  48300,
#  48304,
#  48307,
#  48311,
#  48312,
#  48316,
#  48318,
#  48322,
#  48323,
#  48325,
#  48327,
#  48333,
#  48337,
#  48340,
#  48342,
#  48345,
#  48347,
#  48350,
#  48355,
#  48356,
#  48359,
#  48363,
#  48372,
#  48373,
#  48375,
#  48377,
#  48381,
#  48385,
#  48389,
#  48394,
#  48396,
#  48397,
#  48410,
#  48413,
#  48416,
#  48417,
#  48418,
#  48421,
#  48425,
#  48426,
#  48428,
#  48434,
#  48435,
#  48440,
#  48443,
#  48444,
#  48446,
#  48453,
#  48455,
#  48456,
#  48473,
#  48476,
#  48477,
#  48478,
#  48480,
#  48484,
#  48486,
#  48492,
#  48496,
#  48499,
#  48503,
#  48507,
#  48509,
#  48511,
#  48512,
#  48513,
#  48515,
#  48516,
#  48519,
#  48521,
#  48524,
#  48528,
#  48529,
#  48530,
#  48531,
#  48532,
#  48536,
#  48538,
#  48542,
#  48545,
#  48551,
#  48554,
#  48557,
#  48558,
#  48559,
#  48560,
#  48561,
#  48564,
#  48566,
#  48568,
#  48572,
#  48573,
#  48576,
#  48580,
#  48586,
#  48588,
#  48589,
#  48592,
#  48594,
#  48596,
#  48597,
#  48606,
#  48607,
#  48608,
#  48610,
#  48616,
#  48621,
#  48622,
#  48623,
#  48625,
#  48626,
#  48628,
#  48636,
#  48639,
#  48644,
#  48646,
#  48656,
#  48658,
#  48661,
#  48663,
#  48665,
#  48666,
#  48668,
#  48672,
#  48678,
#  48680,
#  48681,
#  48690,
#  48691,
#  48692,
#  48693,
#  48695,
#  48697,
#  48700,
#  48702,
#  48710,
#  48712,
#  48713,
#  48714,
#  48715,
#  48716,
#  48717,
#  48721,
#  48723,
#  48730,
#  48734,
#  48735,
#  48738,
#  48746,
#  48748,
#  48749,
#  48750,
#  48751,
#  48752,
#  48759,
#  48762,
#  48763,
#  48766,
#  48770,
#  48775,
#  48777,
#  48779,
#  48782,
#  48784,
#  48804,
#  48805,
#  48814,
#  48816,
#  48822,
#  48825,
#  48827,
#  48828,
#  48833,
#  48839,
#  48841,
#  48842,
#  48847,
#  48852,
#  48858,
#  48866,
#  48868,
#  48871,
#  48872,
#  48877,
#  48881,
#  48884,
#  48890,
#  48891,
#  48892,
#  48895,
#  48896,
#  48897,
#  48898,
#  48901,
#  48902,
#  48914,
#  48916,
#  48921,
#  48922,
#  48931,
#  48934,
#  48935,
#  48937,
#  48939,
#  48941,
#  48949,
#  48958,
#  48963,
#  48965,
#  48968,
#  48971,
#  48972,
#  48973,
#  48974,
#  48981,
#  48982,
#  48984,
#  48986,
#  48987,
#  48992,
#  48993,
#  48996,
#  48998,
#  48999,
#  49001,
#  49003,
#  49004,
#  49006,
#  49007,
#  49008,
#  49011,
#  49020,
#  49022,
#  49023,
#  49026,
#  49028,
#  49031,
#  49034,
#  49035,
#  49038,
#  49040,
#  49048,
#  49052,
#  49057,
#  49062,
#  49066,
#  49067,
#  49072,
#  49075,
#  49078,
#  49080,
#  49082,
#  49083,
#  49085,
#  49086,
#  49089,
#  49090,
#  49096,
#  49102,
#  49104,
#  49106,
#  49110,
#  49112,
#  49115,
#  49121,
#  49128,
#  49131,
#  49132,
#  49135,
#  49143,
#  49144,
#  49145,
#  49151,
#  49154,
#  49156,
#  49158,
#  49165,
#  49167,
#  49172,
#  49173,
#  49179,
#  49186,
#  49187,
#  49190,
#  49192,
#  49196,
#  49197,
#  49198,
#  49199,
#  49201,
#  49202,
#  49203,
#  49204,
#  49205,
#  49212,
#  49216,
#  49217,
#  49219,
#  49222,
#  49226,
#  49228,
#  49230,
#  49231,
#  49232,
#  49236,
#  49237,
#  49239,
#  49244,
#  49245,
#  49246,
#  49248,
#  49255,
#  49258,
#  49265,
#  49266,
#  49267,
#  49271,
#  49274,
#  49278,
#  49279,
#  49281,
#  49284,
#  49285,
#  49286,
#  49290,
#  49296,
#  49300,
#  49301,
#  49314,
#  49318,
#  49323,
#  49324,
#  49325,
#  49331,
#  49333,
#  49336,
#  49337,
#  49338,
#  49343,
#  49345,
#  49346,
#  49348,
#  49357,
#  49361,
#  49364,
#  49369,
#  49373,
#  49378,
#  49379,
#  49383,
#  49385,
#  49393,
#  49394,
#  49395,
#  49399,
#  49402,
#  49403,
#  49404,
#  49406,
#  49409,
#  49412,
#  49421,
#  49430,
#  49431,
#  49432,
#  49435,
#  49439,
#  49440,
#  49444,
#  49446,
#  49448,
#  49449,
#  49453,
#  49456,
#  49457,
#  49460,
#  49465,
#  49466,
#  49470,
#  49478,
#  49486,
#  49487,
#  49492,
#  49494,
#  49502,
#  49504,
#  49513,
#  49514,
#  49515,
#  49522,
#  49527,
#  49528,
#  49529,
#  49530,
#  49534,
#  49542,
#  49544,
#  49547,
#  49548,
#  49552,
#  49558,
#  49561,
#  49563,
#  49564,
#  49565,
#  49566,
#  49568,
#  49570,
#  49575,
#  49580,
#  49581,
#  49583,
#  49585,
#  49588,
#  49594,
#  49596,
#  49601,
#  49604,
#  49608,
#  49611,
#  49614,
#  49620,
#  49624,
#  49625,
#  49628,
#  49634,
#  49635,
#  49639,
#  49642,
#  49643,
#  49644,
#  49646,
#  49651,
#  49652,
#  49655,
#  49657,
#  49662,
#  49664,
#  49666,
#  49670,
#  49675,
#  49680,
#  49683,
#  49685,
#  49692,
#  49693,
#  49696,
#  49697,
#  49699,
#  49703,
#  49705,
#  49709,
#  49711,
#  49712,
#  49716,
#  49720,
#  49722,
#  49723,
#  49726,
#  49729,
#  49730,
#  49732,
#  49734,
#  49735,
#  49736,
#  49739,
#  49741,
#  49742,
#  49743,
#  49744,
#  49747,
#  49754,
#  49759,
#  49760,
#  49766,
#  49767,
#  49771,
#  49775,
#  49776,
#  49778,
#  49779,
#  49781,
#  49783,
#  49785,
#  49796,
#  49797,
#  49800,
#  49801,
#  49802,
#  49807,
#  49816,
#  49817,
#  49819,
#  49820,
#  49823,
#  49824,
#  49825,
#  49829,
#  49836,
#  49837,
#  49840,
#  49843,
#  49845,
#  49846,
#  49847,
#  49851,
#  49854,
#  49859,
#  49862,
#  49863,
#  49868,
#  49869,
#  49870,
#  49873,
#  49874,
#  49880,
#  49882,
#  49883,
#  49884,
#  49888,
#  49890,
#  49892,
#  49893,
#  49898,
#  49900,
#  49902,
#  49906,
#  49908,
#  49909,
#  49910,
#  49911,
#  49914,
#  49915,
#  49916,
#  49917,
#  49918,
#  49919,
#  49921,
#  49923,
#  49924,
#  49925,
#  49928,
#  49936,
#  49937,
#  49938,
#  49940,
#  49943,
#  49947,
#  49949,
#  49951,
#  49952,
#  49958,
#  49959,
#  49961,
#  49963,
#  49972,
#  49977,
#  49978,
#  49984,
#  49986,
#  49989,
#  49994,
#  49995,
#  49996,
#  49999,
#  50006,
#  50008,
#  50013,
#  50015,
#  50018,
#  50024,
#  50026,
#  50029,
#  50030,
#  50034,
#  50035,
#  50039,
#  50043,
#  50048,
#  50049,
#  50059,
#  50060,
#  50064,
#  50071,
#  50072,
#  50078,
#  50080,
#  50083,
#  50085,
#  50089,
#  50091,
#  50093,
#  50095,
#  50098,
#  50100,
#  50101,
#  50102,
#  50103,
#  50106,
#  50115,
#  50116,
#  50117,
#  50118,
#  50122,
#  50123,
#  50124,
#  50126,
#  50127,
#  50128,
#  50130,
#  50133,
#  50135,
#  50141,
#  50149,
#  50150,
#  50152,
#  50154,
#  50160,
#  50164,
#  50171,
#  50182,
#  50186,
#  50188,
#  50190,
#  50192,
#  50195,
#  50196,
#  50197,
#  50198,
#  50206,
#  50211,
#  50215,
#  50217,
#  50218,
#  50220,
#  50222,
#  50224,
#  50226,
#  50234,
#  50235,
#  50239,
#  50240,
#  50251,
#  50256,
#  50268,
#  50269,
#  50272,
#  50275,
#  50278,
#  50280,
#  50283,
#  50285,
#  50286,
#  50287,
#  50292,
#  50297,
#  50299,
#  50302,
#  50303,
#  50305,
#  50308,
#  50309,
#  50310,
#  50318,
#  50320,
#  50323,
#  50324,
#  50335,
#  50336,
#  50338,
#  50346,
#  50347,
#  50350,
#  50352,
#  50354,
#  50365,
#  50367,
#  50370,
#  50373,
#  50374,
#  50375,
#  50381,
#  50384,
#  50385,
#  50386,
#  ...]

# %%
tira_cs_asr_idcs = balance_df.loc[tira_cs_idcs, 'asr_index']
tira_cs_asr_idcs=tira_cs_asr_idcs.astype(int).tolist()
tira_cs_asr_idcs[:5]
# Out:
# [2, 3, 8, 14, 15]

# %%
long_csv_path = '/Users/markjos/projects/malachor5/data/elicitation-wavs/autotranscribed/longlabels.csv'
long_df = pd.read_csv(long_csv_path)

# %%
cs_idx_mask = long_df['asr_index'].isin(tira_cs_asr_idcs)
cs_idx_mask.value_counts()
# Out:
# asr_index
# False    15054
# True      5426
# Name: count, dtype: int64

# %% [markdown]
# # Whisper output cleaning
# Figure out what labels are excessive repetitions and exclude

# %%
tokenizer = WhisperTokenizer.from_pretrained('openai/whisper-medium')
df['normalized']=df['transcription'].apply(tokenizer.normalize)
df['normalized']
# Out:
# 0                                 hello hello hello
# 1                     hello hello hello hello hello
# 2                             hello hello this shit
# 3                                                 .
# 4                                 hello hello hello
#                             ...
# 109388                                         okay
# 109389                                         yeah
# 109390    but this really studied with the question
# 109391                                         okay
# 109392             yes i am going to stop recording
# Name: normalized, Length: 109393, dtype: object

# %%
df['transcription']=df['normalized']

# %%
eng_only = lambda s: all(get_word_language(word) == 'eng' for word in s.split())
df['eng_only'] = df['transcription'].apply(eng_only)
df['eng_only'].value_counts()
# Out:
# eng_only
# True     80307
# False    29086
# Name: count, dtype: int64

# %%
# get number of words per sentence
# and number of times most common word repeats
df['num_words']=df['transcription'].str.split().apply(len)
def get_most_freq_word_count(s:str):
    words = s.split()
    words = [x.lower() for x in words]
    if len(words)==0:
        return 0
    return max([words.count(w) for w in words])
df['max_word_count'] = df['transcription'].apply(get_most_freq_word_count)

# %%
(df['max_word_count']<5).value_counts()
# Out:
# max_word_count
# True     105200
# False      4193
# Name: count, dtype: int64

# %%
str_is_punct = lambda s: all(c in punctuation for c in s.strip())
df['is_punct'] = df['transcription'].apply(str_is_punct)
df['is_punct'].value_counts()
# Out:
# is_punct
# False    104488
# True       4905
# Name: count, dtype: int64

# %%
df['is_valid'] = (
    # df['eng_only']&
    (df['eng_only']|(df['sli_pred']=='TIC')) &
    # ~df['is_punct'] &
    (df['max_word_count']<5)
)
df['is_valid'].value_counts()
# Out:
# is_valid
# True     79819
# False    29574
# Name: count, dtype: int64

# %%
long_df['start'].apply(type).value_counts()
# Out:
# start
# <class 'float'>    20480
# Name: count, dtype: int64

# %%
filestem_masks = {
    filestem: df['filestem']==filestem
    for filestem in long_df['filestem'].unique()
}
long_df['is_valid']=True
long_df['clean_transcription']=''
for i, row in tqdm(long_df[cs_idx_mask].iterrows(), total=cs_idx_mask.sum()):
    asr_i = row['asr_index']
    start_mask = df['start']>=row['start']
    end_mask = df['end']<=row['end']
    filestem_mask = filestem_masks[row['filestem']]
    # print(f"{start_mask.sum()=}, {end_mask.sum()=}, {filestem_mask.sum()=}")
    within_label_mask = start_mask&end_mask&filestem_mask
    if (within_label_mask.sum()==0) or ((~df.loc[within_label_mask,'is_valid']).sum()>0):
        long_df.at[i,'is_valid']=False
    transcription_start_tuples = list(zip(
        df.loc[within_label_mask, 'transcription'].tolist(),
        df.loc[within_label_mask, 'start'].tolist(),
    ))
    tira_row_transcription = balance_df.loc[balance_df['asr_index']==asr_i,'transcription'].item()
    tira_row_start = balance_df.loc[balance_df['asr_index']==asr_i,'start'].item()
    transcription_start_tuples.append((tira_row_transcription,tira_row_start))
    transcription_start_tuples.sort(key=lambda t:t[1])
    transcription = ' '.join(t[0] for t in transcription_start_tuples).strip()
    long_df.at[i, 'clean_transcription']=transcription
long_df.loc[tira_cs_asr_idcs, 'is_valid'].value_counts()
# Out:
# 100%|██████████| 5426/5426 [00:09<00:00, 595.84it/s]
# is_valid
# True     4302
# False    1124
# Name: count, dtype: int64

# %%
long_df.loc[cs_idx_mask].pivot_table(values='duration', index='is_valid', aggfunc='sum')/3_600_000
# Out:
#            duration
# is_valid
# False     12.944179
# True       4.455045

# %%
cs_valid = long_df.loc[cs_idx_mask,'is_valid']
cs_clean_df = long_df.loc[cs_idx_mask][cs_valid]
cs_clean_df['clean_transcription'].sample().item()
# Out:
# 'i will see you next time there is a couple of things on it i am going to go to the next slide and my recent effort was to get a quarter of a school on the standard thank you that he is proof of your hearing yesterday i am going to go ahead and close out the meeting thank you kìjɔ́ ŋɔ́mɔ̀ nɛ̀ ŋɛ́t̪ì ŋìjà unɛɾɛ'

# %%
cs_clean_df=cs_clean_df.rename(columns={
    'transcription': 'old_transcription',
    'clean_transcription': 'transcription',
})
cs_clean_df.head()
# Out:
#      asr_index      start        end  \
# 14     15002.0  2479097.0  2502863.0
# 116    15913.0  2976459.0  3006329.0
# 137    18476.0   577040.0   604965.0
# 138    17383.0   193548.0   220165.0
# 196     5597.0   966408.0   991538.0
#
#                                      old_transcription  \
# 14   lárɔ̄lɛ́ úrnɔ̀ lə̀gwɔ̀t̪ɔ́ ɔ́ɟɔ́ únɛ̀rɛ̀ Th...
# 116  íŋgánɔ́nà ŋòðà ŋɛ́ jámlá nd̪ɔ̀bà Okay,...
# 137  ŋùdúŋàɲà ŋìcə̀lò But we actually have th...
# 138  ðàmɔ̀cò ðə̀bùlìjí ápríɲâ Okay, I guess...
# 196  lìɟí là ílə̀ðɛ̀ dìjò Okay. All right, th...
#
#                                       indices  duration  split  \
# 14                       [116952, 47979, 129]   23766.0  train
# 116         [117863, 541, 8229, 32428, 51514]   29870.0  train
# 137                       [120426, 4143, 587]   27925.0  train
# 138                      [119333, 588, 89877]   26617.0  train
# 196  [107547, 86807, 2033, 86808, 763, 99138]   25130.0  train
#
#               filestem                                       wav_source  \
# 14          HH04092021         data/elicitation-wavs/wav/HH04092021.wav
# 116  HH20230420-2-Zoom  data/elicitation-wavs/wav/HH20230420-2-Zoom.wav
# 137       HH20230717-1       data/elicitation-wavs/wav/HH20230717-1.wav
# 138         HH20210326         data/elicitation-wavs/wav/HH20210326.wav
# 196       HH20220111-3       data/elicitation-wavs/wav/HH20220111-3.wav
#
#      is_valid                                      transcription
# 14       True  lárɔ̄lɛ́ úrnɔ̀ lə̀gwɔ̀t̪ɔ́ ɔ́ɟɔ́ únɛ̀rɛ̀ th...
# 116      True  íŋgánɔ́nà ŋòðà ŋɛ́ jámlá nd̪ɔ̀bà okay ...
# 137      True  ŋùdúŋàɲà ŋìcə̀lò but we actually have th...
# 138      True  ðàmɔ̀cò ðə̀bùlìjí ápríɲâ  okay i guess...
# 196      True  lìɟí là ílə̀ðɛ̀ dìjò okay all right ther...

# %%
cs_clean_dir = '/Users/markjos/projects/malachor5/data/hf-datasets/tira_cs_clean'
cs_clean_metadata = '/Users/markjos/projects/malachor5/data/hf-datasets/tira_cs_clean/metadata.csv'
cs_clean_df.to_csv(cs_clean_metadata, index=False)

# %%
longlabels_hf_ds_metadata_path = '/Users/markjos/projects/malachor5/data/hf-datasets/tira-longlabels/metadata.csv'
longlabels_hf_dir = '/Users/markjos/projects/malachor5/data/hf-datasets/tira-longlabels'
longlabels_hf = pd.read_csv(longlabels_hf_ds_metadata_path, index_col='asr_index')
longlabels_hf.head()
# Out:
#                start        end  \
# asr_index
# 11230.0    1229590.0  1259547.0
# 14569.0     902320.0   930910.0
# 14538.0    1318720.0  1344900.0
# 12250.0    3154322.0  3184300.0
# 6154.0     1148379.0  1177450.0
#
#                                                transcription  \
# asr_index
# 11230.0    íŋgánɔ̀nà ɛ́léɲé kə́ náɾùwè nd̪ɔ̀bà T...
# 14569.0    weird tone patterns. And so that might either ...
# 14538.0    làdɔ́ŋnɛ̀ nìðìnɔ́ŋù ùnɛ̀ɾɛ̀ So actually, ...
# 12250.0    from the Karcha, Karcha is actually far away. ...
# 6154.0     íŋgáðə́rɔ̀ðà You know, our friend, El Yasse...
#
#                                                      indices  duration  split  \
# asr_index
# 11230.0    [113180, 69522, 101459, 10, 36988, 69525, 7323...   29957.0  train
# 14569.0                                         [42, 116519]   28590.0  train
# 14538.0                                         [116488, 59]   26180.0  train
# 12250.0    [31526, 72251, 64, 49843, 37711, 19284, 70756,...   29978.0  train
# 6154.0                      [108104, 86, 9008, 63666, 48904]   29071.0  train
#
#                     filestem                                       wav_source  \
# asr_index
# 11230.0         HH20220719-2       data/elicitation-wavs/wav/HH20220719-2.wav
# 14569.0    HH20230414-Zoom-3  data/elicitation-wavs/wav/HH20230414-Zoom-3.wav
# 14538.0         HH20220629-2       data/elicitation-wavs/wav/HH20220629-2.wav
# 12250.0           HH20221127         data/elicitation-wavs/wav/HH20221127.wav
# 6154.0      HH07242020-Zoom2   data/elicitation-wavs/wav/HH07242020-Zoom2.wav
#
#                                                    file_name
# asr_index
# 11230.0    clips/train/HH20220719-2-m20.0s29.0ms590.0-m20...
# 14569.0    clips/train/HH20230414-Zoom-3-m15.0s2.0ms320.0...
# 14538.0    clips/train/HH20220629-2-m21.0s58.0ms720.0-m22...
# 12250.0    clips/train/HH20221127-m52.0s34.0ms322.0-m53.0...
# 6154.0     clips/train/HH07242020-Zoom2-m19.0s8.0ms379.0-...

# %%
os.makedirs(
    os.path.join(cs_clean_dir, 'clips', 'train'), exist_ok=True
)

def copy_to_clean_ds(asr_index):
    clip_relpath = longlabels_hf.loc[asr_index, 'file_name']
    assert type(clip_relpath) is str
    shutil.copy(
        os.path.join(longlabels_hf_dir, clip_relpath),
        os.path.join(cs_clean_dir, clip_relpath)
    )

    return clip_relpath

cs_clean_df['file_name'] = cs_clean_df['asr_index'].progress_apply(copy_to_clean_ds)
# Out:
# 100%|██████████| 1152/1152 [00:02<00:00, 430.55it/s]

# %%
cs_clean_df.to_csv(cs_clean_metadata, index=False)

# %%
ds = load_dataset('audiofolder', data_dir=cs_clean_dir)
ds.save_to_disk(cs_clean_dir.replace('hf-datasets', 'pyarrow-datasets'))
# Out:
# Resolving data files: 100%|██████████| 1152/1152 [00:00<00:00, 168491.76it/s]
# Downloading data files: 100%|██████████| 1153/1153 [00:00<00:00, 25235.78it/s]
# Downloading data files: 0it [00:00, ?it/s]
# Extracting data files: 0it [00:00, ?it/s]
# Generating train split: 1152 examples [00:00, 2155.92 examples/s]
# Saving the dataset (3/3 shards): 100%|██████████| 1152/1152 [00:03<00:00, 314.17 examples/s]
