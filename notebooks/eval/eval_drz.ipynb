# %%
import pandas as pd

# %%
vad_csv = '../../data/longform-drz/vad_eval.csv'
df = pd.read_csv(vad_csv)
df.head()
# Out:
#     speaker  correct  missed detection  false alarm  confusion     total  \
# 0  combined  587.031          1427.615      539.126    218.352  2232.998
# 1       SHA  259.958           337.943          NaN      3.882   601.783
# 2       NIN   64.774           101.980          NaN      0.610   167.364
# 3       HIM  212.974           639.640          NaN    127.618   980.232
# 4       MAR    0.000             0.000          NaN      0.000     0.000
#
#    diarization error rate  eng correct  eng total  eng missed detection  ...  \
# 0                0.978547      587.031   1695.829              1108.798  ...
# 1                     NaN      259.958    586.944               326.986  ...
# 2                     NaN       64.774    165.492               100.718  ...
# 3                     NaN      127.618    478.493               350.875  ...
# 4                     NaN        0.000      0.000                 0.000  ...
#
# ...

# %%
df.loc[df['file']=='average', [col for col in df.columns if 'rate' in col or col=='speaker']]
# Out:
#      speaker  diarization error rate  correct rate  missed detection rate  \
# 48  combined                1.343963      0.330406               0.512748
# 49       SHA                     NaN      0.387111               0.455174
# 50       NIN                     NaN      0.292096               0.317572
# 51       HIM                     NaN      0.304441               0.504534
# 52       MAR                     NaN      0.013775               0.111225
# 53       PET                     NaN      0.230486               0.240134
# 54  combined                1.343963      0.330406               0.512748
# 55       SHA                     NaN      0.387111               0.455174
# 56       NIN                     NaN      0.292096               0.317572
# 57       HIM                     NaN      0.304441               0.504534
# 58       MAR                     NaN      0.013775               0.111225
# 59       PET                     NaN      0.230486               0.240134
# ...
