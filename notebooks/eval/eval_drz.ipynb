# %%
import pandas as pd

# %%
vad_csv = '../../data/longform-drz/drz3.1_eval.csv'
df = pd.read_csv(vad_csv)
df.head()
# Out:
#     speaker     total  confusion  correct  false alarm  missed detection  \
# 0  combined  1704.076    174.314  513.160      520.302          1016.602
# 1       SHA   500.543      1.710  236.446          NaN           262.387
# 2       NIN   137.414      0.110   61.126          NaN            76.178
# 3       HIM   728.721     96.487  171.370          NaN           460.864
# 4       MAR     0.000      0.000    0.000          NaN             0.000
#
#    diarization error rate  eng correct  eng total  eng missed detection  ...  \
# 0                1.004191      515.656   1328.101               812.445  ...
# 1                     NaN      236.446    491.664               255.218  ...
# 2                     NaN       61.126    136.542                75.416  ...
# 3                     NaN       96.487    361.123               264.636  ...
# 4                     NaN        0.000      0.000                 0.000  ...
#
# ...

# %%
df.loc[df['file']=='average', [col for col in df.columns if 'rate' in col or col=='speaker']].iloc[:6]
# Out:
#      speaker  diarization error rate  confusion rate  correct rate  \
# 48  combined                1.609815        0.170060      0.376170
# 49       SHA                     NaN        0.030429      0.428457
# 50       NIN                     NaN        0.014508      0.316744
# 51       HIM                     NaN        0.209005      0.330602
# 52       MAR                     NaN        0.000000      0.011630
# 53       PET                     NaN        0.031147      0.264086
#
#     false alarm rate  missed detection rate  eng correct rate  \
# 48          0.985985               0.453770          0.546088
# 49               NaN               0.416114          0.456166
# 50               NaN               0.293748          0.331401
# 51               NaN               0.460393          0.524420
# 52               NaN               0.113370          0.011630
# 53               NaN               0.204767          0.295563
#
# ...

# %%
df.loc[(df['speaker']=='combined') & (df['file']!='average'), [col for col in df.columns if 'rate' in col or col=='file']]
# Out:
#     diarization error rate  confusion rate  correct rate  false alarm rate  \
# 0                 1.004191        0.102292      0.301137          0.305328
# 6                 2.779235        0.175946      0.442345          2.221580
# 12                0.908909        0.107903      0.284271          0.193180
# 18                1.238564        0.233993      0.314017          0.552581
# 24                0.986975        0.068470      0.304932          0.291906
# 30                0.961204        0.170145      0.408990          0.370193
# 36                4.567099        0.192583      0.347903          3.915002
# 42                0.432346        0.309150      0.605762          0.038109
#
#     missed detection rate  eng correct rate  eng missed detection rate  \
# 0                0.596571          0.388266                   0.611734
# 6                0.381709          0.645210                   0.354790
# 12               0.607826          0.364944                   0.635056
# ...
