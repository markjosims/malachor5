# %%
import pandas as pd

# %%
vad_csv = '../../data/longform-drz/vad_eval.csv'
df = pd.read_csv(vad_csv)
df.head()
# Out:
#    Unnamed: 0   speaker  missed detection  false alarm  confusion  correct  \
# 0           0  combined          2232.998          0.0        0.0      0.0
# 1           1       SHA           601.783          NaN        0.0      0.0
# 2           2       NIN           167.364          NaN        0.0      0.0
# 3           3       HIM           980.232          NaN        0.0      0.0
# 4           4       MAR             0.000          NaN        0.0      0.0
#
#       total  identification error rate  eng false alarm  eng correct  ...  \
# 0  2232.998                        1.0              0.0          0.0  ...
# 1   601.783                        NaN              NaN          0.0  ...
# 2   167.364                        NaN              NaN          0.0  ...
# 3   980.232                        NaN              NaN          0.0  ...
# 4     0.000                        NaN              NaN          0.0  ...
#
#    correct rate  eng false alarm rate  eng correct rate  \
# ...
