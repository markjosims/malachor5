# %%
import numpy as np
import torch
import pandas as pd
import json
from torch.nn.functional import cosine_similarity
from glob import glob
cosine = lambda *args: cosine_similarity(*args, dim=0).item()
from scipy.spatial.distance import cosine, pdist, squareform
import seaborn
import matplotlib.pyplot as plt

# %%
whisper_embeds_path = '../data/whisper_embeds/whisper_embeds.pt'
tira_embed_path = '../data/whisper_embeds/tira-asr-orig-test.pt'
tira_embed_1k = '../data/whisper_embeds/tira-1k-hf-train.pt'
tira_embed_1k_concat = '../data/whisper_embeds/tira-concat-1k-hf-train.pt'
commonvoice_embeds_path = '/Users/markjos/projects/malachor5/data/commonvoice/'

# %%
fleurs_embeds = torch.load(whisper_embeds_path)
# clean up keys
fleurs_embeds={k.split('-')[1]: v for k,v in fleurs_embeds.items()}
fleurs_embeds.keys()
# Out:
# dict_keys(['it_it', 'lt_lt', 'hu_hu', 'nb_no', 'fr_fr', 'tr_tr', 'ln_cd', 'az_az', 'uz_uz', 'kk_kz', 'ar_eg', 'km_kh', 'el_gr', 'te_in', 'sw_ke', 'hi_in', 'sk_sk', 'mk_mk', 'sn_zw', 'fi_fi', 'mr_in', 'ca_es', 'fa_ir', 'as_in', 'hy_am', 'ro_ro', 'lb_lu', 'mn_mn', 'oc_fr', 'bg_bg', 'et_ee', 'vi_vn', 'sd_in', 'ur_pk', 'ps_af', 'es_419', 'ne_np', 'lv_lv', 'bn_in', 'tg_tj', 'ka_ge', 'ru_ru', 'mt_mt', 'uk_ua', 'lo_la', 'mi_nz', 'hr_hr', 'ja_jp', 'is_is', 'yo_ng', 'ta_in', 'sr_rs', 'sv_se', 'jv_id', 'pt_br', 'da_dk', 'ko_kr', 'sl_si', 'af_za', 'th_th', 'ml_in', 'ha_ng', 'bs_ba', 'so_so', 'cy_gb', 'he_il', 'pl_pl', 'nl_nl', 'gl_es', 'ms_my', 'be_by', 'am_et', 'de_de', 'en_us', 'id_id', 'gu_in', 'kn_in', 'cs_cz', 'pa_in', 'asr'])

# %%
commonvoice_embeds_files = glob(commonvoice_embeds_path+'*.pt')
commonvoice_embeds_files
# Out:
# ['/Users/markjos/projects/malachor5/data/commonvoice/common_voice_13_0-en-train.pt',
#  '/Users/markjos/projects/malachor5/data/commonvoice/common_voice_13_0-ar-train.pt',
#  '/Users/markjos/projects/malachor5/data/commonvoice/common_voice_13_0-tr-train.pt',
#  '/Users/markjos/projects/malachor5/data/commonvoice/common_voice_13_0-vi-train.pt',
#  '/Users/markjos/projects/malachor5/data/commonvoice/common_voice_13_0-id-train.pt',
#  '/Users/markjos/projects/malachor5/data/commonvoice/common_voice_13_0-fr-train.pt',
#  '/Users/markjos/projects/malachor5/data/commonvoice/common_voice_13_0-ja-train.pt',
#  '/Users/markjos/projects/malachor5/data/commonvoice/common_voice_13_0-de-train.pt',
#  '/Users/markjos/projects/malachor5/data/commonvoice/common_voice_13_0-sv-SE-train.pt',
#  '/Users/markjos/projects/malachor5/data/commonvoice/common_voice_13_0-ru-train.pt',
#  '/Users/markjos/projects/malachor5/data/commonvoice/common_voice_13_0-hi-train.pt',
#  '/Users/markjos/projects/malachor5/data/commonvoice/common_voice_13_0-nl-train.pt',
#  '/Users/markjos/projects/malachor5/data/commonvoice/common_voice_13_0-es-train.pt',
#  '/Users/markjos/projects/malachor5/data/commonvoice/common_voice_13_0-fi-train.pt',
#  '/Users/markjos/projects/malachor5/data/commonvoice/common_voice_13_0-pl-train.pt',
#  '/Users/markjos/projects/malachor5/data/commonvoice/common_voice_13_0-yo-train.pt',
#  '/Users/markjos/projects/malachor5/data/commonvoice/common_voice_13_0-it-train.pt',
#  '/Users/markjos/projects/malachor5/data/commonvoice/common_voice_13_0-ko-train.pt',
#  '/Users/markjos/projects/malachor5/data/commonvoice/common_voice_13_0-ca-train.pt',
#  '/Users/markjos/projects/malachor5/data/commonvoice/common_voice_13_0-pt-train.pt']

# %%
commonvoice_embeds={embed_file.split('-')[-2]: torch.load(embed_file) for embed_file in commonvoice_embeds_files}
commonvoice_embeds.keys()
# Out:
# dict_keys(['en', 'ar', 'tr', 'vi', 'id', 'fr', 'ja', 'de', 'SE', 'ru', 'hi', 'nl', 'es', 'fi', 'pl', 'yo', 'it', 'ko', 'ca', 'pt'])

# %%
tira_embeds = torch.load(tira_embed_1k)
tira_embeds_concat = torch.load(tira_embed_1k_concat)
tira_embeds.shape, tira_embeds_concat.shape
# Out:
# (torch.Size([1280]), torch.Size([1280]))

# %%
lang_code_path = '../meta/language_codes.json'
with open(lang_code_path) as f:
    lang_code_dict = json.load(f)
lang_code_dict
# Out:
# [{'iso2': 'en',
#   'iso3': 'eng',
#   'whisper': 'english',
#   'fleurs': 'en_us',
#   'fleurs_script': 'Latn',
#   'commonvoice_code': 'en',
#   'commonvoice_name': 'English'},
#  {'iso2': 'de',
#   'iso3': 'deu',
#   'whisper': 'german',
#   'fleurs': 'de_de',
#   'fleurs_script': 'Latn',
#   'commonvoice_code': 'de',
#   'commonvoice_name': 'German'},
#  {'iso2': 'es',
#   'iso3': 'spa',
#   'whisper': 'spanish',
#   'fleurs': 'es_419',
#   'fleurs_script': 'Latn',
#   'commonvoice_code': 'es',
#   'commonvoice_name': 'Spanish'},
#  {'iso2': 'ru',
#   'iso3': 'rus',
#   'whisper': 'russian',
#   'fleurs': 'ru_ru',
#   'fleurs_script': 'Cyrl',
#   'commonvoice_code': 'ru',
#   'commonvoice_name': 'Russian'},
#  {'iso2': 'ko',
#   'iso3': 'kor',
#   'whisper': 'korean',
#   'fleurs': 'ko_kr',
#   'fleurs_script': 'Hang',
#   'commonvoice_code': 'ko',
#   'commonvoice_name': 'Korean'},
#  {'iso2': 'fr',
#   'iso3': 'fra',
#   'whisper': 'french',
#   'fleurs': 'fr_fr',
#   'fleurs_script': 'Latn',
#   'commonvoice_code': 'fr',
#   'commonvoice_name': 'French'},
#  {'iso2': 'ja',
#   'iso3': 'jpn',
#   'whisper': 'japanese',
#   'fleurs': 'ja_jp',
#   'fleurs_script': '',
#   'commonvoice_code': 'ja',
#   'commonvoice_name': 'Japanese'},
#  {'iso2': 'pt',
#   'iso3': 'por',
#   'whisper': 'portuguese',
#   'fleurs': 'pt_br',
#   'fleurs_script': 'Latn',
#   'commonvoice_code': 'pt',
#   'commonvoice_name': 'Portuguese'},
#  {'iso2': 'tr',
#   'iso3': 'tur',
#   'whisper': 'turkish',
#   'fleurs': 'tr_tr',
#   'fleurs_script': 'Latn',
#   'commonvoice_code': 'tr',
#   'commonvoice_name': 'Turkish'},
#  {'iso2': 'pl',
#   'iso3': 'pol',
#   'whisper': 'polish',
#   'fleurs': 'pl_pl',
#   'fleurs_script': 'Latn',
#   'commonvoice_code': 'pl',
#   'commonvoice_name': 'Polish'},
#  {'iso2': 'ca',
#   'iso3': 'cat',
#   'whisper': 'catalan',
#   'fleurs': 'ca_es',
#   'fleurs_script': 'Latn',
#   'commonvoice_code': 'ca',
#   'commonvoice_name': 'Catalan'},
#  {'iso2': 'nl',
#   'iso3': 'nld',
#   'whisper': 'dutch',
#   'fleurs': 'nl_nl',
#   'fleurs_script': 'Latn',
#   'commonvoice_code': 'nl',
#   'commonvoice_name': 'Dutch'},
#  {'iso2': 'ar',
#   'iso3': 'ara',
#   'whisper': 'arabic',
#   'fleurs': 'ar_eg',
#   'fleurs_script': 'Arab',
#   'commonvoice_code': 'ar',
#   'commonvoice_name': 'Arabic'},
#  {'iso2': 'sv',
#   'iso3': 'swe',
#   'whisper': 'swedish',
#   'fleurs': 'sv_se',
#   'fleurs_script': 'Latn',
#   'commonvoice_code': 'sv-SE',
#   'commonvoice_name': 'Swedish'},
#  {'iso2': 'it',
#   'iso3': 'ita',
#   'whisper': 'italian',
#   'fleurs': 'it_it',
#   'fleurs_script': 'Latn',
#   'commonvoice_code': 'it',
#   'commonvoice_name': 'Italian'},
#  {'iso2': 'id',
#   'iso3': 'ind',
#   'whisper': 'indonesian',
#   'fleurs': 'id_id',
#   'fleurs_script': 'Latn',
#   'commonvoice_code': 'id',
#   'commonvoice_name': 'Indonesian'},
#  {'iso2': 'hi',
#   'iso3': 'hin',
#   'whisper': 'hindi',
#   'fleurs': 'hi_in',
#   'fleurs_script': 'Deva',
#   'commonvoice_code': 'hi',
#   'commonvoice_name': 'Hindi'},
#  {'iso2': 'fi',
#   'iso3': 'fin',
#   'whisper': 'finnish',
#   'fleurs': 'fi_fi',
#   'fleurs_script': 'Latn',
#   'commonvoice_code': 'fi',
#   'commonvoice_name': 'Finnish'},
#  {'iso2': 'vi',
#   'iso3': 'vie',
#   'whisper': 'vietnamese',
#   'fleurs': 'vi_vn',
#   'fleurs_script': 'Latn',
#   'commonvoice_code': 'vi',
#   'commonvoice_name': 'Vietnamese'},
#  {'iso2': 'he',
#   'iso3': 'heb',
#   'whisper': 'hebrew',
#   'fleurs': 'he_il',
#   'fleurs_script': '',
#   'commonvoice_code': 'he',
#   'commonvoice_name': 'Hebrew'},
#  {'iso2': 'uk',
#   'iso3': 'ukr',
#   'whisper': 'ukrainian',
#   'fleurs': 'uk_ua',
#   'fleurs_script': 'Cyrl',
#   'commonvoice_code': 'uk',
#   'commonvoice_name': 'Ukrainian'},
#  {'iso2': 'el',
#   'iso3': 'ell',
#   'whisper': 'greek',
#   'fleurs': 'el_gr',
#   'fleurs_script': '',
#   'commonvoice_code': 'el',
#   'commonvoice_name': 'Greek'},
#  {'iso2': 'ms',
#   'iso3': 'msa',
#   'whisper': 'malay',
#   'fleurs': 'ms_my',
#   'fleurs_script': 'Latn',
#   'commonvoice_code': 'ms',
#   'commonvoice_name': 'Malay'},
#  {'iso2': 'cs',
#   'iso3': 'ces',
#   'whisper': 'czech',
#   'fleurs': 'cs_cz',
#   'fleurs_script': 'Latn',
#   'commonvoice_code': 'cs',
#   'commonvoice_name': 'Czech'},
#  {'iso2': 'ro',
#   'iso3': 'ron',
#   'whisper': 'romanian',
#   'fleurs': 'ro_ro',
#   'fleurs_script': 'Latn',
#   'commonvoice_code': 'ro',
#   'commonvoice_name': 'Romanian'},
#  {'iso2': 'da',
#   'iso3': 'dan',
#   'whisper': 'danish',
#   'fleurs': 'da_dk',
#   'fleurs_script': 'Latn',
#   'commonvoice_code': 'da',
#   'commonvoice_name': 'Danish'},
#  {'iso2': 'hu',
#   'iso3': 'hun',
#   'whisper': 'hungarian',
#   'fleurs': 'hu_hu',
#   'fleurs_script': 'Latn',
#   'commonvoice_code': 'hu',
#   'commonvoice_name': 'Hungarian'},
#  {'iso2': 'ta',
#   'iso3': 'tam',
#   'whisper': 'tamil',
#   'fleurs': 'ta_in',
#   'fleurs_script': 'Taml',
#   'commonvoice_code': 'ta',
#   'commonvoice_name': 'Tamil'},
#  {'iso2': 'no',
#   'iso3': 'nor',
#   'whisper': 'norwegian',
#   'fleurs': 'nb_no',
#   'fleurs_script': 'Latn'},
#  {'iso2': 'th',
#   'iso3': 'tha',
#   'whisper': 'thai',
#   'fleurs': 'th_th',
#   'fleurs_script': 'Thai',
#   'commonvoice_code': 'th',
#   'commonvoice_name': 'Thai'},
#  {'iso2': 'ur',
#   'iso3': 'urd',
#   'whisper': 'urdu',
#   'fleurs': 'ur_pk',
#   'fleurs_script': 'Arab',
#   'commonvoice_code': 'ur',
#   'commonvoice_name': 'Urdu'},
#  {'iso2': 'hr',
#   'iso3': 'hrv',
#   'whisper': 'croatian',
#   'fleurs': 'hr_hr',
#   'fleurs_script': 'Latn',
#   'commonvoice_code': 'hr',
#   'commonvoice_name': 'Croatian'},
#  {'iso2': 'bg',
#   'iso3': 'bul',
#   'whisper': 'bulgarian',
#   'fleurs': 'bg_bg',
#   'fleurs_script': 'Latn',
#   'commonvoice_code': 'bg',
#   'commonvoice_name': 'Bulgarian'},
#  {'iso2': 'lt',
#   'iso3': 'lit',
#   'whisper': 'lithuanian',
#   'fleurs': 'lt_lt',
#   'fleurs_script': 'Latn',
#   'commonvoice_code': 'lt',
#   'commonvoice_name': 'Lithuanian'},
#  {'iso2': 'mi',
#   'iso3': 'mri',
#   'whisper': 'maori',
#   'fleurs': 'mi_nz',
#   'fleurs_script': 'Latin'},
#  {'iso2': 'ml',
#   'iso3': 'mal',
#   'whisper': 'malayalam',
#   'fleurs': 'ml_in',
#   'fleurs_script': '',
#   'commonvoice_code': 'ml',
#   'commonvoice_name': 'Malayalam'},
#  {'iso2': 'cy',
#   'iso3': 'cym',
#   'whisper': 'welsh',
#   'fleurs': 'cy_gb',
#   'fleurs_script': 'Latn',
#   'commonvoice_code': 'cy',
#   'commonvoice_name': 'Welsh'},
#  {'iso2': 'sk',
#   'iso3': 'slk',
#   'whisper': 'slovak',
#   'fleurs': 'sk_sk',
#   'fleurs_script': 'Latn',
#   'commonvoice_code': 'sk',
#   'commonvoice_name': 'Slovak'},
#  {'iso2': 'te',
#   'iso3': 'tel',
#   'whisper': 'telugu',
#   'fleurs': 'te_in',
#   'fleurs_script': 'Telu',
#   'commonvoice_code': 'te',
#   'commonvoice_name': 'Telugu'},
#  {'iso2': 'fa',
#   'iso3': 'fas',
#   'whisper': 'persian',
#   'fleurs': 'fa_ir',
#   'fleurs_script': 'Arab',
#   'commonvoice_code': 'fa',
#   'commonvoice_name': 'Persian'},
#  {'iso2': 'lv',
#   'iso3': 'lav',
#   'whisper': 'latvian',
#   'fleurs': 'lv_lv',
#   'fleurs_script': 'Latn',
#   'commonvoice_code': 'lv',
#   'commonvoice_name': 'Latvian'},
#  {'iso2': 'bn',
#   'iso3': 'ben',
#   'whisper': 'bengali',
#   'fleurs': 'bn_in',
#   'fleurs_script': 'Beng',
#   'commonvoice_code': 'bn',
#   'commonvoice_name': 'Bengali'},
#  {'iso2': 'sr',
#   'iso3': 'srp',
#   'whisper': 'serbian',
#   'fleurs': 'sr_rs',
#   'fleurs_script': 'Latn',
#   'commonvoice_code': 'sr',
#   'commonvoice_name': 'Serbian'},
#  {'iso2': 'az',
#   'iso3': 'aze',
#   'whisper': 'azerbaijani',
#   'fleurs': 'az_az',
#   'fleurs_script': 'Latn',
#   'commonvoice_code': 'az',
#   'commonvoice_name': 'Azerbaijani'},
#  {'iso2': 'sl',
#   'iso3': 'slv',
#   'whisper': 'slovenian',
#   'fleurs': 'sl_si',
#   'fleurs_script': 'Latn',
#   'commonvoice_code': 'sl',
#   'commonvoice_name': 'Slovenian'},
#  {'iso2': 'kn',
#   'iso3': 'kan',
#   'whisper': 'kannada',
#   'fleurs': 'kn_in',
#   'fleurs_script': '',
#   'commonvoice_code': 'kn',
#   'commonvoice_name': 'Kannada'},
#  {'iso2': 'et',
#   'iso3': 'est',
#   'whisper': 'estonian',
#   'fleurs': 'et_ee',
#   'fleurs_script': 'Latn',
#   'commonvoice_code': 'et',
#   'commonvoice_name': 'Estonian'},
#  {'iso2': 'mk',
#   'iso3': 'mkd',
#   'whisper': 'macedonian',
#   'fleurs': 'mk_mk',
#   'fleurs_script': '',
#   'commonvoice_code': 'mk',
#   'commonvoice_name': 'Macedonian'},
#  {'iso2': 'is',
#   'iso3': 'isl',
#   'whisper': 'icelandic',
#   'fleurs': 'is_is',
#   'fleurs_script': 'Latn',
#   'commonvoice_code': 'is',
#   'commonvoice_name': 'Icelandic'},
#  {'iso2': 'hy',
#   'iso3': 'hye',
#   'whisper': 'armenian',
#   'fleurs': 'hy_am',
#   'fleurs_script': '',
#   'commonvoice_code': 'hyw',
#   'commonvoice_name': 'Armenian Western'},
#  {'iso2': 'ne',
#   'iso3': 'nep',
#   'whisper': 'nepali',
#   'fleurs': 'ne_np',
#   'fleurs_script': '',
#   'commonvoice_code': 'ne-NP',
#   'commonvoice_name': 'Nepali'},
#  {'iso2': 'mn',
#   'iso3': 'mon',
#   'whisper': 'mongolian',
#   'fleurs': 'mn_mn',
#   'fleurs_script': 'Cyrl',
#   'commonvoice_code': 'mn',
#   'commonvoice_name': 'Mongolian'},
#  {'iso2': 'bs',
#   'iso3': 'bos',
#   'whisper': 'bosnian',
#   'fleurs': 'bs_ba',
#   'fleurs_script': '',
#   'commonvoice_code': 'bs',
#   'commonvoice_name': 'Bosnian'},
#  {'iso2': 'kk',
#   'iso3': 'kaz',
#   'whisper': 'kazakh',
#   'fleurs': 'kk_kz',
#   'fleurs_script': '',
#   'commonvoice_code': 'kk',
#   'commonvoice_name': 'Kazakh'},
#  {'iso2': 'sw',
#   'iso3': 'swa',
#   'whisper': 'swahili',
#   'fleurs': 'sw_ke',
#   'fleurs_script': 'Latn',
#   'commonvoice_code': 'sw',
#   'commonvoice_name': 'Swahili'},
#  {'iso2': 'gl',
#   'iso3': 'glg',
#   'whisper': 'galician',
#   'fleurs': 'gl_es',
#   'fleurs_script': 'Latn',
#   'commonvoice_code': 'gl',
#   'commonvoice_name': 'Galician'},
#  {'iso2': 'mr',
#   'iso3': 'mar',
#   'whisper': 'marathi',
#   'fleurs': 'mr_in',
#   'fleurs_script': 'Deva',
#   'commonvoice_code': 'mr',
#   'commonvoice_name': 'Marathi'},
#  {'iso2': 'pa',
#   'iso3': 'pan',
#   'whisper': 'punjabi',
#   'fleurs': 'pa_in',
#   'fleurs_script': 'Guru',
#   'commonvoice_code': 'pa-IN',
#   'commonvoice_name': 'Punjabi'},
#  {'iso2': 'km',
#   'iso3': 'khm',
#   'whisper': 'khmer',
#   'fleurs': 'km_kh',
#   'fleurs_script': 'Khmr',
#   'commonvoice_code': 'km',
#   'commonvoice_name': 'Khmer'},
#  {'iso2': 'sn',
#   'iso3': 'sna',
#   'whisper': 'shona',
#   'fleurs': 'sn_zw',
#   'fleurs_script': 'Latn'},
#  {'iso2': 'yo',
#   'iso3': 'yor',
#   'whisper': 'yoruba',
#   'fleurs': 'yo_ng',
#   'fleurs_script': 'Latn',
#   'commonvoice_code': 'yo',
#   'commonvoice_name': 'Yoruba'},
#  {'iso2': 'so',
#   'iso3': 'som',
#   'whisper': 'somali',
#   'fleurs': 'so_so',
#   'fleurs_script': 'Latn',
#   'commonvoice_code': 'so',
#   'commonvoice_name': 'Somali'},
#  {'iso2': 'af',
#   'iso3': 'afr',
#   'whisper': 'afrikaans',
#   'fleurs': 'af_za',
#   'fleurs_script': 'Latn',
#   'commonvoice_code': 'af',
#   'commonvoice_name': 'Afrikaans'},
#  {'iso2': 'oc',
#   'iso3': 'oci',
#   'whisper': 'occitan',
#   'fleurs': 'oc_fr',
#   'fleurs_script': 'Latn',
#   'commonvoice_code': 'oc',
#   'commonvoice_name': 'Occitan'},
#  {'iso2': 'ka',
#   'iso3': 'kat',
#   'whisper': 'georgian',
#   'fleurs': 'ka_ge',
#   'fleurs_script': '',
#   'commonvoice_code': 'ka',
#   'commonvoice_name': 'Georgian'},
#  {'iso2': 'be',
#   'iso3': 'bel',
#   'whisper': 'belarusian',
#   'fleurs': 'be_by',
#   'fleurs_script': 'Cyrl',
#   'commonvoice_code': 'be',
#   'commonvoice_name': 'Belarusian'},
#  {'iso2': 'tg',
#   'iso3': 'tgk',
#   'whisper': 'tajik',
#   'fleurs': 'tg_tj',
#   'fleurs_script': 'Cyrl',
#   'commonvoice_code': 'tg',
#   'commonvoice_name': 'Tajik'},
#  {'iso2': 'sd',
#   'iso3': 'snd',
#   'whisper': 'sindhi',
#   'fleurs': 'sd_in',
#   'fleurs_script': '',
#   'commonvoice_code': 'sd',
#   'commonvoice_name': 'Sindhi'},
#  {'iso2': 'gu',
#   'iso3': 'guj',
#   'whisper': 'gujarati',
#   'fleurs': 'gu_in',
#   'fleurs_script': '',
#   'commonvoice_code': 'gu-IN',
#   'commonvoice_name': 'Gujarati'},
#  {'iso2': 'am',
#   'iso3': 'amh',
#   'whisper': 'amharic',
#   'fleurs': 'am_et',
#   'fleurs_script': 'Ethi',
#   'commonvoice_code': 'am',
#   'commonvoice_name': 'Amharic'},
#  {'iso2': 'lo',
#   'iso3': 'lao',
#   'whisper': 'lao',
#   'fleurs': 'lo_la',
#   'fleurs_script': 'Latn',
#   'commonvoice_code': 'lo',
#   'commonvoice_name': 'Lao'},
#  {'iso2': 'uz',
#   'iso3': 'uzb',
#   'whisper': 'uzbek',
#   'fleurs': 'uz_uz',
#   'fleurs_script': '',
#   'commonvoice_code': 'uz',
#   'commonvoice_name': 'Uzbek'},
#  {'iso2': 'ps',
#   'iso3': 'pus',
#   'whisper': 'pashto',
#   'fleurs': 'ps_af',
#   'fleurs_script': '',
#   'commonvoice_code': 'ps',
#   'commonvoice_name': 'Pashto'},
#  {'iso2': 'mt',
#   'iso3': 'mlt',
#   'whisper': 'maltese',
#   'fleurs': 'mt_mt',
#   'fleurs_script': 'Latn',
#   'commonvoice_code': 'mt',
#   'commonvoice_name': 'Maltese'},
#  {'iso2': 'lb',
#   'iso3': 'ltz',
#   'whisper': 'luxembourgish',
#   'fleurs': 'lb_lu',
#   'fleurs_script': 'Latn',
#   'commonvoice_code': 'lb',
#   'commonvoice_name': 'Luxembourgish'},
#  {'iso2': 'as',
#   'iso3': 'asm',
#   'whisper': 'assamese',
#   'fleurs': 'as_in',
#   'fleurs_script': '',
#   'commonvoice_code': 'as',
#   'commonvoice_name': 'Assamese'},
#  {'iso2': 'ln',
#   'iso3': 'lin',
#   'whisper': 'lingala',
#   'fleurs': 'ln_cd',
#   'fleurs_script': '',
#   'commonvoice_code': 'ln',
#   'commonvoice_name': 'Lingala'},
#  {'iso2': 'ha',
#   'iso3': 'hau',
#   'whisper': 'hausa',
#   'fleurs': 'ha_ng',
#   'fleurs_script': 'Latn',
#   'commonvoice_code': 'ha',
#   'commonvoice_name': 'Hausa'},
#  {'iso2': 'jv',
#   'iso3': 'jav',
#   'whisper': 'javanese',
#   'fleurs': 'jv_id',
#   'fleurs_script': 'Latn',
#   'commonvoice_code': 'jv',
#   'commonvoice_name': 'Javanese'},
#  {'iso2': 'zh',
#   'iso3': 'zho',
#   'whisper': 'chinese',
#   'fleurs': 'cmn_hans',
#   'fleurs_script': 'Hans',
#   'commonvoice_code': 'zh-TW',
#   'commonvoice_name': 'Chinese (Taiwan)'},
#  {'iso2': 'yue',
#   'iso3': 'yue',
#   'whisper': 'cantonese',
#   'fleurs': 'yue_hant',
#   'fleurs_script': '',
#   'commonvoice_code': 'yue',
#   'commonvoice_name': 'Cantonese'},
#  {'iso2': 'tl',
#   'iso3': 'tgl',
#   'whisper': 'tagalog',
#   'fleurs': 'fil',
#   'fleurs_script': 'Latn',
#   'commonvoice_code': 'tl',
#   'commonvoice_name': 'Tagalog'},
#  {'iso2': 'my',
#   'iso3': 'mya',
#   'whisper': 'myanmar',
#   'fleurs': 'my_mm',
#   'fleurs_script': 'Mymr',
#   'commonvoice_code': 'my',
#   'commonvoice_name': 'Burmese'},
#  {'commonvoice_code': 'ab', 'commonvoice_name': 'Abkhaz'},
#  {'commonvoice_code': 'ab', 'commonvoice_name': 'Abkhaz'},
#  {'commonvoice_code': 'ace', 'commonvoice_name': 'Acehnese'},
#  {'commonvoice_code': 'ady', 'commonvoice_name': 'Adyghe'},
#  {'commonvoice_code': 'an', 'commonvoice_name': 'Aragonese'},
#  {'commonvoice_code': 'arn', 'commonvoice_name': 'Mapudungun'},
#  {'commonvoice_code': 'ast', 'commonvoice_name': 'Asturian'},
#  {'commonvoice_code': 'ba', 'commonvoice_name': 'Bashkir'},
#  {'commonvoice_code': 'bas', 'commonvoice_name': 'Basaa'},
#  {'commonvoice_code': 'bm', 'commonvoice_name': 'Bambara'},
#  {'commonvoice_code': 'bo', 'commonvoice_name': 'Tibetan'},
#  {'commonvoice_code': 'br', 'commonvoice_name': 'Breton'},
#  {'commonvoice_code': 'bxr', 'commonvoice_name': 'Buryat'},
#  {'commonvoice_code': 'byv', 'commonvoice_name': 'Medumba'},
#  {'commonvoice_code': 'cak', 'commonvoice_name': 'Kaqchikel'},
#  {'commonvoice_code': 'ckb', 'commonvoice_name': 'Central Kurdish'},
#  {'commonvoice_code': 'cnh', 'commonvoice_name': 'Hakha Chin'},
#  {'commonvoice_code': 'co', 'commonvoice_name': 'Corsican'},
#  {'commonvoice_code': 'cv', 'commonvoice_name': 'Chuvash'},
#  {'commonvoice_code': 'dag', 'commonvoice_name': 'Dagbani'},
#  {'commonvoice_code': 'dsb', 'commonvoice_name': 'Sorbian, Lower'},
#  {'commonvoice_code': 'dv', 'commonvoice_name': 'Dhivehi'},
#  {'commonvoice_code': 'dyu', 'commonvoice_name': 'Dioula'},
#  {'commonvoice_code': 'eo', 'commonvoice_name': 'Esperanto'},
#  {'commonvoice_code': 'eu', 'commonvoice_name': 'Basque'},
#  {'commonvoice_code': 'ff', 'commonvoice_name': 'Fulah'},
#  {'commonvoice_code': 'fo', 'commonvoice_name': 'Faroese'},
#  {'commonvoice_code': 'fy-NL', 'commonvoice_name': 'Frisian'},
#  {'commonvoice_code': 'ga-IE', 'commonvoice_name': 'Irish'},
#  {'commonvoice_code': 'gn', 'commonvoice_name': 'Guarani'},
#  {'commonvoice_code': 'gom', 'commonvoice_name': 'Goan Konkani'},
#  {'commonvoice_code': 'hil', 'commonvoice_name': 'Hiligaynon'},
#  {'commonvoice_code': 'hsb', 'commonvoice_name': 'Sorbian, Upper'},
#  {'commonvoice_code': 'ht', 'commonvoice_name': 'Haitian'},
#  {'commonvoice_code': 'hyw', 'commonvoice_name': 'Armenian Western'},
#  {'commonvoice_code': 'ia', 'commonvoice_name': 'Interlingua'},
#  {'commonvoice_code': 'ie', 'commonvoice_name': 'Interlingue'},
#  {'commonvoice_code': 'ig', 'commonvoice_name': 'Igbo'},
#  {'commonvoice_code': 'izh', 'commonvoice_name': 'Izhorian'},
#  {'commonvoice_code': 'jbo', 'commonvoice_name': 'Lojban'},
#  {'commonvoice_code': 'kaa', 'commonvoice_name': 'Karakalpak'},
#  {'commonvoice_code': 'kab', 'commonvoice_name': 'Kabyle'},
#  {'commonvoice_code': 'kbd', 'commonvoice_name': 'Kabardian'},
#  {'commonvoice_code': 'ki', 'commonvoice_name': 'Kikuyu'},
#  {'commonvoice_code': 'kmr', 'commonvoice_name': 'Kurmanji Kurdish'},
#  {'commonvoice_code': 'knn', 'commonvoice_name': 'Konkani (Devanagari)'},
#  {'commonvoice_code': 'kpv', 'commonvoice_name': 'Komi-Zyrian'},
#  {'commonvoice_code': 'kw', 'commonvoice_name': 'Cornish'},
#  {'commonvoice_code': 'ky', 'commonvoice_name': 'Kyrgyz'},
#  {'commonvoice_code': 'lg', 'commonvoice_name': 'Luganda'},
#  {'commonvoice_code': 'lij', 'commonvoice_name': 'Ligurian'},
#  {'commonvoice_code': 'mai', 'commonvoice_name': 'Maithili'},
#  {'commonvoice_code': 'mdf', 'commonvoice_name': 'Moksha'},
#  {'commonvoice_code': 'mg', 'commonvoice_name': 'Malagasy'},
#  {'commonvoice_code': 'mhr', 'commonvoice_name': 'Meadow Mari'},
#  {'commonvoice_code': 'mni', 'commonvoice_name': 'Meetei Lon'},
#  {'commonvoice_code': 'mos', 'commonvoice_name': 'Mossi'},
#  {'commonvoice_code': 'mrj', 'commonvoice_name': 'Hill Mari'},
#  {'commonvoice_code': 'myv', 'commonvoice_name': 'Erzya'},
#  {'commonvoice_code': 'nan-tw', 'commonvoice_name': 'Taiwanese (Minnan)'},
#  {'commonvoice_code': 'nb-NO', 'commonvoice_name': 'Norwegian Bokmål'},
#  {'commonvoice_code': 'nr', 'commonvoice_name': 'IsiNdebele (South)'},
#  {'commonvoice_code': 'nhe', 'commonvoice_name': 'Eastern Huasteca Nahuatl'},
#  {'commonvoice_code': 'nhi',
#   'commonvoice_name': 'Western Sierra Puebla Nahuatl'},
#  {'commonvoice_code': 'nia', 'commonvoice_name': 'Nias'},
#  {'commonvoice_code': 'nn-NO', 'commonvoice_name': 'Norwegian Nynorsk'},
#  {'commonvoice_code': 'nr', 'commonvoice_name': 'IsiNdebele (South)'},
#  {'commonvoice_code': 'nso', 'commonvoice_name': 'Northern Sotho'},
#  {'commonvoice_code': 'ny', 'commonvoice_name': 'Chinyanja'},
#  {'commonvoice_code': 'nyn', 'commonvoice_name': 'Runyankole'},
#  {'commonvoice_code': 'om', 'commonvoice_name': 'Afaan Oromo'},
#  {'commonvoice_code': 'or', 'commonvoice_name': 'Odia'},
#  {'commonvoice_code': 'pap-AW', 'commonvoice_name': 'Papiamento (Aruba)'},
#  {'commonvoice_code': 'quc', 'commonvoice_name': "K'iche'"},
#  {'commonvoice_code': 'quy', 'commonvoice_name': 'Quechua Chanka'},
#  {'commonvoice_code': 'rm-sursilv', 'commonvoice_name': 'Romansh Sursilvan'},
#  {'commonvoice_code': 'rm-vallader', 'commonvoice_name': 'Romansh Vallader'},
#  {'commonvoice_code': 'rw', 'commonvoice_name': 'Kinyarwanda'},
#  {'commonvoice_code': 'sah', 'commonvoice_name': 'Sakha'},
#  {'commonvoice_code': 'sat', 'commonvoice_name': 'Santali (Ol Chiki)'},
#  {'commonvoice_code': 'sc', 'commonvoice_name': 'Sardinian'},
#  {'commonvoice_code': 'scn', 'commonvoice_name': 'Sicilian'},
#  {'commonvoice_code': 'sdh', 'commonvoice_name': 'Southern Kurdish'},
#  {'commonvoice_code': 'shi', 'commonvoice_name': 'Shilha'},
#  {'commonvoice_code': 'si', 'commonvoice_name': 'Sinhala'},
#  {'commonvoice_code': 'skr', 'commonvoice_name': 'Saraiki'},
#  {'commonvoice_code': 'snk', 'commonvoice_name': 'Soninke'},
#  {'commonvoice_code': 'sq', 'commonvoice_name': 'Albanian'},
#  {'commonvoice_code': 'ss', 'commonvoice_name': 'Siswati'},
#  {'commonvoice_code': 'st', 'commonvoice_name': 'Southern Sotho'},
#  {'commonvoice_code': 'syr', 'commonvoice_name': 'Syriac'},
#  {'commonvoice_code': 'ti', 'commonvoice_name': 'Tigrinya'},
#  {'commonvoice_code': 'tig', 'commonvoice_name': 'Tigre'},
#  {'commonvoice_code': 'tk', 'commonvoice_name': 'Turkmen'},
#  {'commonvoice_code': 'tn', 'commonvoice_name': 'Setswana'},
#  {'commonvoice_code': 'tok', 'commonvoice_name': 'Toki Pona'},
#  {'commonvoice_code': 'ts', 'commonvoice_name': 'Xitsonga'},
#  {'commonvoice_code': 'tt', 'commonvoice_name': 'Tatar'},
#  {'commonvoice_code': 'tw', 'commonvoice_name': 'Twi'},
#  {'commonvoice_code': 'ty', 'commonvoice_name': 'Tahitian'},
#  {'commonvoice_code': 'tyv', 'commonvoice_name': 'Tuvan'},
#  {'commonvoice_code': 'uby', 'commonvoice_name': 'Ubykh'},
#  {'commonvoice_code': 'udm', 'commonvoice_name': 'Udmurt'},
#  {'commonvoice_code': 'ug', 'commonvoice_name': 'Uyghur'},
#  {'commonvoice_code': 've', 'commonvoice_name': 'Tshivenda'},
#  {'commonvoice_code': 'vec', 'commonvoice_name': 'Venetian'},
#  {'commonvoice_code': 'vot', 'commonvoice_name': 'Votic'},
#  {'commonvoice_code': 'wo', 'commonvoice_name': 'Wolof'},
#  {'commonvoice_code': 'xh', 'commonvoice_name': 'Xhosa'},
#  {'commonvoice_code': 'yi', 'commonvoice_name': 'Yiddish'},
#  {'commonvoice_code': 'zgh', 'commonvoice_name': 'Tamazight'},
#  {'commonvoice_code': 'zh-CN', 'commonvoice_name': 'Chinese (China)'},
#  {'commonvoice_code': 'zh-HK', 'commonvoice_name': 'Chinese (Hong Kong)'},
#  {'commonvoice_code': 'zh-TW', 'commonvoice_name': 'Chinese (Taiwan)'},
#  {'commonvoice_code': 'zu', 'commonvoice_name': 'Zulu'},
#  {'commonvoice_code': 'zza', 'commonvoice_name': 'Zaza'},
#  {'commonvoice_code': 'bxr', 'commonvoice_name': 'Buryat'},
#  {'commonvoice_code': 'crh', 'commonvoice_name': 'Crimean Tatar'},
#  {'commonvoice_code': 'ewo', 'commonvoice_name': 'Ewondo'},
#  {'commonvoice_code': 'fuf', 'commonvoice_name': 'Pular Guinea'},
#  {'commonvoice_code': 'fy-NL', 'commonvoice_name': 'Frisian'},
#  {'commonvoice_code': 'ga-IE', 'commonvoice_name': 'Irish'},
#  {'commonvoice_code': 'guc', 'commonvoice_name': 'Wayuunaiki'},
#  {'commonvoice_code': 'knn', 'commonvoice_name': 'Konkani (Devanagari)'},
#  {'commonvoice_code': 'ltg', 'commonvoice_name': 'Latgalian'},
#  {'commonvoice_code': 'lzz', 'commonvoice_name': 'Laz'},
#  {'commonvoice_code': 'mhr', 'commonvoice_name': 'Meadow Mari'},
#  {'commonvoice_code': 'nan-tw', 'commonvoice_name': 'Taiwanese (Minnan)'},
#  {'commonvoice_code': 'nb-NO', 'commonvoice_name': 'Norwegian Bokmål'},
#  {'commonvoice_code': 'nn-NO', 'commonvoice_name': 'Norwegian Nynorsk'},
#  {'commonvoice_code': 'os', 'commonvoice_name': 'Ossetian'},
#  {'commonvoice_code': 'pap-AW', 'commonvoice_name': 'Papiamento (Aruba)'},
#  {'commonvoice_code': 'quy', 'commonvoice_name': 'Quechua Chanka'},
#  {'commonvoice_code': 'qvi', 'commonvoice_name': 'Kichwa'},
#  {'commonvoice_code': 'rm-sursilv', 'commonvoice_name': 'Romansh Sursilvan'},
#  {'commonvoice_code': 'rm-vallader', 'commonvoice_name': 'Romansh Vallader'},
#  {'commonvoice_code': 'sco', 'commonvoice_name': 'Scots'},
#  {'commonvoice_code': 'vmw', 'commonvoice_name': 'Emakhuwa'},
#  {'commonvoice_code': 'wep', 'commonvoice_name': 'Westphalian'},
#  {'commonvoice_code': 'zgh', 'commonvoice_name': 'Tamazight'}]

# %%
def dist_matrix(embeds_dict):
    embeds_tensor=torch.stack([t for t in embeds_dict.values()])
    dist_mat=squareform(pdist(embeds_tensor,cosine))
    dist_mat.shape
    dist_df=pd.DataFrame(dist_mat, index=embeds_dict.keys(), columns=embeds_dict.keys())
    fig, ax = plt.subplots(figsize=(10,10))
    seaborn.heatmap(dist_df, cmap='YlGnBu')
dist_matrix({'tira':tira_embeds, **commonvoice_embeds, **fleurs_embeds})
