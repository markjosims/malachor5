# %%
import pandas as pd
from pydub import AudioSegment

# %%
csv_path='../data/tira-asr-hf/metadata-combined.csv'
df=pd.read_csv(csv_path, keep_default_na=False)
df.head()
# Out:
#       start       end                                      transcription  \
# 0  184240.0  189330.0  mə̀nà càt̪á án âjt̪ɔ́ ŋìðə̀nɔ́ŋ ŋírɔ́t̪...
# 1  271280.0  272310.0                                    íŋgáŋâɽìɲǎ
# 2  275030.0  276050.0                                    íŋgáŋâɽìɲǎ
# 3  304295.0  305015.0                                    íŋgáŋâɽìɲǎ
# 4  331510.0  333800.0                      ŋìðə̀ní ŋrɔ̀t̪ɔ́ t̪ɔ́wə̀nì
#
#                                           eaf_source  \
# 0  /Users/markjos/Library/CloudStorage/GoogleDriv...
# 1  /Users/markjos/Library/CloudStorage/GoogleDriv...
# 2  /Users/markjos/Library/CloudStorage/GoogleDriv...
# 3  /Users/markjos/Library/CloudStorage/GoogleDriv...
# 4  /Users/markjos/Library/CloudStorage/GoogleDriv...
#
#                                           wav_source  \
# 0  /Users/markjos/Library/CloudStorage/GoogleDriv...
# 1  /Users/markjos/Library/CloudStorage/GoogleDriv...
# 2  /Users/markjos/Library/CloudStorage/GoogleDriv...
# 3  /Users/markjos/Library/CloudStorage/GoogleDriv...
# 4  /Users/markjos/Library/CloudStorage/GoogleDriv...
#
#                                    raw_transcription  \
# 0  mə̀nà tʃàt̪á án âjt̪ɔ́ ŋìðə̀nɔ́ŋ ŋírɔ́t...
# 1                                    íŋgáŋâɽìɲǎ
# 2                                    íŋgáŋâɽìɲǎ
# 3                                    íŋgáŋâɽìɲǎ
# 4                         ŋìðə̀ní ŋrɔ̀t̪ɔ́ t̪ɔ́wə̀nì
#
#                                                 clip  \
# 0  data/tira-asr/clips/HH20220719-1-m03s04ms240-m...
# 1  data/tira-asr/clips/HH20220719-1-m04s31ms280-m...
# 2  data/tira-asr/clips/HH20220719-1-m04s35ms030-m...
# 3  data/tira-asr/clips/HH20220719-1-m05s04ms295-m...
# 4  data/tira-asr/clips/HH20220719-1-m05s31ms510-m...
#
#                                          wav_rawpath  \
# 0  /Users/markjos/Library/CloudStorage/GoogleDriv...
# 1  /Users/markjos/Library/CloudStorage/GoogleDriv...
# 2  /Users/markjos/Library/CloudStorage/GoogleDriv...
# 3  /Users/markjos/Library/CloudStorage/GoogleDriv...
# 4  /Users/markjos/Library/CloudStorage/GoogleDriv...
#
#                                            file_name  \
# 0  data/tira-asr/clips/HH20220719-1-m03s04ms240-m...
# 1  data/tira-asr/clips/HH20220719-1-m04s31ms280-m...
# 2  data/tira-asr/clips/HH20220719-1-m04s35ms030-m...
# 3  data/tira-asr/clips/HH20220719-1-m05s04ms295-m...
# 4  data/tira-asr/clips/HH20220719-1-m05s31ms510-m...
#
#                                        path  \
# 0  HH20220719-1-m03s04ms240-m03s09ms330.wav
# 1  HH20220719-1-m04s31ms280-m04s32ms310.wav
# 2  HH20220719-1-m04s35ms030-m04s36ms050.wav
# 3  HH20220719-1-m05s04ms295-m05s05ms015.wav
# 4  HH20220719-1-m05s31ms510-m05s33ms800.wav
#
#                                           allosaurus  clap_ipa_cos_sim  \
# 0  m ɛ m a k a t̪ a n a j t̪ a ð ɛ n e ɔ r a d̪ e...          0.673431
# 1                            ɲ i n k a ŋ n a d i ɲ a          0.523998
# 2                                  i ɲ t a ŋ a ɲ j a          0.527971
# 3                                          t a ŋ v a          0.616754
# 4                   e v e m e ŋ n r o a t̪ ɔ t o n e          0.749451
#
#     wada_snr  nist_stnr   speaker-diarization-3.1  \
# 0  14.081620      25.00  0.031 5.009 SPEAKER_00\n
# 1   5.625207      16.25  0.031 1.094 SPEAKER_00\n
# 2   4.222627      20.00  0.031 1.060 SPEAKER_00\n
# 3   2.189131       3.50  0.031 0.773 SPEAKER_00\n
# 4  15.113453      26.00  0.031 2.191 SPEAKER_00\n
#
#                  voice-activity-detection  \
# 0  0.031 3.642 SPEECH;4.098 4.942 SPEECH;
# 1                     0.098 1.043 SPEECH;
# 2                     0.031 0.959 SPEECH;
# 3                     0.031 0.723 SPEECH;
# 4                     0.031 2.191 SPEECH;
#
#                                     whisper-large-v3  \
# 0   ለለለለለለለለለለለለለለለለለለለለለለለለለለለለለለለለለለለለለለለለለለለለለ...
# 1                                   hingga nganginya
# 2                                      Gak ngalirnya
# 3                                   gone already now
# 4                               Ngini ngroto tawoni.
#
#    clapipa-transcription-allosaurus
# 0                            0.7697
# 1                            0.7191
# 2                            0.5247
# 3                            0.1008
# 4                            0.7299

# %%
df['speaker-diarization-3.1']=df['speaker-diarization-3.1'].apply(lambda s: s.replace('\n', '; ').strip().removesuffix(';'))
df['speaker-diarization-3.1']
# Out:
# 0        0.031 5.009 SPEAKER_00
# 1        0.031 1.094 SPEAKER_00
# 2        0.031 1.060 SPEAKER_00
# 3        0.031 0.773 SPEAKER_00
# 4        0.031 2.191 SPEAKER_00
#                   ...
# 23456    0.031 2.545 SPEAKER_00
# 23457    0.031 3.068 SPEAKER_00
# 23458    0.031 1.870 SPEAKER_00
# 23459    0.031 2.528 SPEAKER_00
# 23460    0.031 2.343 SPEAKER_00
# Name: speaker-diarization-3.1, Length: 23461, dtype: object

# %%
df['voice-activity-detection']=df['voice-activity-detection'].apply(lambda s: s.replace('\n', '; ').strip().removesuffix(';'))
df['voice-activity-detection']
# Out:
# 0                    0.031 3.642 SPEECH;4.098 4.942 SPEECH
# 1                                       0.098 1.043 SPEECH
# 2                                       0.031 0.959 SPEECH
# 3                                       0.031 0.723 SPEECH
# 4                                       0.031 2.191 SPEECH
#                                ...
# 23456                0.132 1.482 SPEECH;2.090 2.478 SPEECH
# 23457    0.183 0.942 SPEECH;1.212 1.769 SPEECH;2.512 2....
# 23458                                   0.267 1.887 SPEECH
# 23459                0.031 0.942 SPEECH;1.685 2.444 SPEECH
# 23460                0.065 1.347 SPEECH;1.651 2.292 SPEECH
# Name: voice-activity-detection, Length: 23461, dtype: object

# %%
def get_speech_time(s):
    segments = s.split(sep=';')
    duration=0
    for segment in segments:
        if not segment:
            continue
        start, end = segment.split()[:2]
        start, end = float(start), float(end)
        duration+=end-start
    return duration
df['vad_s']=df['voice-activity-detection'].apply(get_speech_time)
df['drz_s']=df['speaker-diarization-3.1'].apply(get_speech_time)
df
# Out:
#            start        end  \
# 0       184240.0   189330.0
# 1       271280.0   272310.0
# 2       275030.0   276050.0
# 3       304295.0   305015.0
# 4       331510.0   333800.0
# ...          ...        ...
# 23456  2237782.0  2240488.0
# 23457  2249861.0  2252982.0
# 23458  2313888.0  2315750.0
# 23459   212061.0   214567.0
# 23460   266973.0   269277.0
#
#                                            transcription  \
# 0      mə̀nà càt̪á án âjt̪ɔ́ ŋìðə̀nɔ́ŋ ŋírɔ́t̪...
# 1                                        íŋgáŋâɽìɲǎ
# 2                                        íŋgáŋâɽìɲǎ
# 3                                        íŋgáŋâɽìɲǎ
# 4                          ŋìðə̀ní ŋrɔ̀t̪ɔ́ t̪ɔ́wə̀nì
# ...                                                  ...
# 23456                   t̪àrɔ́t̪ɛ́ t̪á úrnɔ̀ t̪àŋòŋ
# 23457                   t̪àrɔ́t̪ɛ́ t̪á úrnɔ̀ t̪àŋòŋ
# 23458                        t̪àrɔ́ŋt̪ɛ́ t̪á t̪àŋòŋs
# 23459                                      ŋárðó lúó
# 23460                                 ŋgá ŋárðà lùò
#
#                                               eaf_source  \
# 0      /Users/markjos/Library/CloudStorage/GoogleDriv...
# 1      /Users/markjos/Library/CloudStorage/GoogleDriv...
# 2      /Users/markjos/Library/CloudStorage/GoogleDriv...
# 3      /Users/markjos/Library/CloudStorage/GoogleDriv...
# 4      /Users/markjos/Library/CloudStorage/GoogleDriv...
# ...                                                  ...
# 23456  /Users/markjos/Library/CloudStorage/GoogleDriv...
# 23457  /Users/markjos/Library/CloudStorage/GoogleDriv...
# 23458  /Users/markjos/Library/CloudStorage/GoogleDriv...
# 23459  /Users/markjos/Library/CloudStorage/GoogleDriv...
# 23460  /Users/markjos/Library/CloudStorage/GoogleDriv...
#
#                                               wav_source  \
# 0      /Users/markjos/Library/CloudStorage/GoogleDriv...
# 1      /Users/markjos/Library/CloudStorage/GoogleDriv...
# 2      /Users/markjos/Library/CloudStorage/GoogleDriv...
# 3      /Users/markjos/Library/CloudStorage/GoogleDriv...
# 4      /Users/markjos/Library/CloudStorage/GoogleDriv...
# ...                                                  ...
# 23456  /Users/markjos/Library/CloudStorage/GoogleDriv...
# 23457  /Users/markjos/Library/CloudStorage/GoogleDriv...
# 23458  /Users/markjos/Library/CloudStorage/GoogleDriv...
# 23459  /Users/markjos/Library/CloudStorage/GoogleDriv...
# 23460  /Users/markjos/Library/CloudStorage/GoogleDriv...
#
#                                        raw_transcription  \
# 0      mə̀nà tʃàt̪á án âjt̪ɔ́ ŋìðə̀nɔ́ŋ ŋírɔ́t...
# 1                                        íŋgáŋâɽìɲǎ
# 2                                        íŋgáŋâɽìɲǎ
# 3                                        íŋgáŋâɽìɲǎ
# 4                             ŋìðə̀ní ŋrɔ̀t̪ɔ́ t̪ɔ́wə̀nì
# ...                                                  ...
# 23456                   t̪àrɔ́t̪ɛ́ t̪á úrnɔ̀ t̪àŋòŋ
# 23457                   t̪àrɔ́t̪ɛ́ t̪á úrnɔ̀ t̪àŋòŋ
# 23458                        t̪àrɔ́ŋt̪ɛ́ t̪á t̪àŋòŋs
# 23459                                      ŋárðó lúó
# 23460                                 ŋɡá ŋárðà lùò
#
#                                                     clip  \
# 0      data/tira-asr/clips/HH20220719-1-m03s04ms240-m...
# 1      data/tira-asr/clips/HH20220719-1-m04s31ms280-m...
# 2      data/tira-asr/clips/HH20220719-1-m04s35ms030-m...
# 3      data/tira-asr/clips/HH20220719-1-m05s04ms295-m...
# 4      data/tira-asr/clips/HH20220719-1-m05s31ms510-m...
# ...                                                  ...
# 23456  data/tira-asr/clips/HH20210830-m37s17ms782-m37...
# 23457  data/tira-asr/clips/HH20210830-m37s29ms861-m37...
# 23458  data/tira-asr/clips/HH20210830-m38s33ms888-m38...
# 23459  data/tira-asr/clips/HH10142020-m03s32ms061-m03...
# 23460  data/tira-asr/clips/HH10142020-m04s26ms973-m04...
#
#                                              wav_rawpath  \
# 0      /Users/markjos/Library/CloudStorage/GoogleDriv...
# 1      /Users/markjos/Library/CloudStorage/GoogleDriv...
# 2      /Users/markjos/Library/CloudStorage/GoogleDriv...
# 3      /Users/markjos/Library/CloudStorage/GoogleDriv...
# 4      /Users/markjos/Library/CloudStorage/GoogleDriv...
# ...                                                  ...
# 23456  /Users/markjos/Library/CloudStorage/GoogleDriv...
# 23457  /Users/markjos/Library/CloudStorage/GoogleDriv...
# 23458  /Users/markjos/Library/CloudStorage/GoogleDriv...
# 23459  /Users/markjos/Library/CloudStorage/GoogleDriv...
# 23460  /Users/markjos/Library/CloudStorage/GoogleDriv...
#
#                                                file_name  \
# 0      data/tira-asr/clips/HH20220719-1-m03s04ms240-m...
# 1      data/tira-asr/clips/HH20220719-1-m04s31ms280-m...
# 2      data/tira-asr/clips/HH20220719-1-m04s35ms030-m...
# 3      data/tira-asr/clips/HH20220719-1-m05s04ms295-m...
# 4      data/tira-asr/clips/HH20220719-1-m05s31ms510-m...
# ...                                                  ...
# 23456  data/tira-asr/clips/HH20210830-m37s17ms782-m37...
# 23457  data/tira-asr/clips/HH20210830-m37s29ms861-m37...
# 23458  data/tira-asr/clips/HH20210830-m38s33ms888-m38...
# 23459  data/tira-asr/clips/HH10142020-m03s32ms061-m03...
# 23460  data/tira-asr/clips/HH10142020-m04s26ms973-m04...
#
#                                            path  \
# 0      HH20220719-1-m03s04ms240-m03s09ms330.wav
# 1      HH20220719-1-m04s31ms280-m04s32ms310.wav
# 2      HH20220719-1-m04s35ms030-m04s36ms050.wav
# 3      HH20220719-1-m05s04ms295-m05s05ms015.wav
# 4      HH20220719-1-m05s31ms510-m05s33ms800.wav
# ...                                         ...
# 23456    HH20210830-m37s17ms782-m37s20ms488.wav
# 23457    HH20210830-m37s29ms861-m37s32ms982.wav
# 23458    HH20210830-m38s33ms888-m38s35ms750.wav
# 23459    HH10142020-m03s32ms061-m03s34ms567.wav
# 23460    HH10142020-m04s26ms973-m04s29ms277.wav
#
#                                               allosaurus  clap_ipa_cos_sim  \
# 0      m ɛ m a k a t̪ a n a j t̪ a ð ɛ n e ɔ r a d̪ e...          0.673431
# 1                                ɲ i n k a ŋ n a d i ɲ a          0.523998
# 2                                      i ɲ t a ŋ a ɲ j a          0.527971
# 3                                              t a ŋ v a          0.616754
# 4                       e v e m e ŋ n r o a t̪ ɔ t o n e          0.749451
# ...                                                  ...               ...
# 23456                       t a r u d̪ ɛ t a o r d a t a          0.727120
# 23457              t̪ a r u t ɛ t̪ t a b u r n ɔ k a m u          0.729792
# 23458                         t a r o ŋ t̪ e t a t a m u          0.627996
# 23459                                  m a r a w a b u a          0.703528
# 23460                                    d a m a r v l u          0.755051
#
#         wada_snr  nist_stnr speaker-diarization-3.1  \
# 0      14.081620      25.00  0.031 5.009 SPEAKER_00
# 1       5.625207      16.25  0.031 1.094 SPEAKER_00
# 2       4.222627      20.00  0.031 1.060 SPEAKER_00
# 3       2.189131       3.50  0.031 0.773 SPEAKER_00
# 4      15.113453      26.00  0.031 2.191 SPEAKER_00
# ...          ...        ...                     ...
# 23456  18.312846      24.00  0.031 2.545 SPEAKER_00
# 23457  18.265378      23.50  0.031 3.068 SPEAKER_00
# 23458  10.120812      15.50  0.031 1.870 SPEAKER_00
# 23459  53.690837      38.00  0.031 2.528 SPEAKER_00
# 23460  22.774613      44.75  0.031 2.343 SPEAKER_00
#
#                                 voice-activity-detection  \
# 0                  0.031 3.642 SPEECH;4.098 4.942 SPEECH
# 1                                     0.098 1.043 SPEECH
# 2                                     0.031 0.959 SPEECH
# 3                                     0.031 0.723 SPEECH
# 4                                     0.031 2.191 SPEECH
# ...                                                  ...
# 23456              0.132 1.482 SPEECH;2.090 2.478 SPEECH
# 23457  0.183 0.942 SPEECH;1.212 1.769 SPEECH;2.512 2....
# 23458                                 0.267 1.887 SPEECH
# 23459              0.031 0.942 SPEECH;1.685 2.444 SPEECH
# 23460              0.065 1.347 SPEECH;1.651 2.292 SPEECH
#
#                                         whisper-large-v3  \
# 0       ለለለለለለለለለለለለለለለለለለለለለለለለለለለለለለለለለለለለለለለለለለለለለ...
# 1                                       hingga nganginya
# 2                                          Gak ngalirnya
# 3                                       gone already now
# 4                                   Ngini ngroto tawoni.
# ...                                                  ...
# 23456                         Tarote ta orna, ta nganta.
# 23457                            taroteta, horno, chamo.
# 23458                                   Tarungte tatamu.
# 23459                                        nada, luego
# 23460                                     Gangerda. Lua.
#
#        clapipa-transcription-allosaurus  vad_s  drz_s
# 0                                0.7697  4.455  4.978
# 1                                0.7191  0.945  1.063
# 2                                0.5247  0.928  1.029
# 3                                0.1008  0.692  0.742
# 4                                0.7299  2.160  2.160
# ...                                 ...    ...    ...
# 23456                            0.8200  1.738  2.514
# 23457                            0.7678  1.704  3.037
# 23458                            0.7912  1.620  1.839
# 23459                            0.4902  1.670  2.497
# 23460                            0.4929  1.923  2.312
#
# [23461 rows x 20 columns]

# %%
df['pcnt_speech']=df['vad_s']*1000/(df['end']-df['start'])
df['pcnt_speech']
# Out:
# 0        0.875246
# 1        0.917476
# 2        0.909804
# 3        0.961111
# 4        0.943231
#            ...
# 23456    0.642276
# 23457    0.545979
# 23458    0.870032
# 23459    0.666401
# 23460    0.834635
# Name: pcnt_speech, Length: 23461, dtype: float64

# %%
df['trans_len']=df['transcription'].str.len()

# %%
df[['vad_s', 'drz_s', 'trans_len']].corr()
# Out:
#                 vad_s     drz_s  trans_len  pcnt_speech
# vad_s        1.000000  0.961224   0.690099    -0.049453
# drz_s        0.961224  1.000000   0.671353    -0.203867
# trans_len    0.690099  0.671353   1.000000    -0.028107
# pcnt_speech -0.049453 -0.203867  -0.028107     1.000000

# %%
df[['pcnt_speech', 'clap_ipa_cos_sim']].corr()
# Out:
#                   pcnt_speech  clap_ipa_cos_sim
# pcnt_speech          1.000000          0.121759
# clap_ipa_cos_sim     0.121759          1.000000

# %%
df.boxplot('pcnt_speech')
# Out:
# <Axes: >

# %%
AudioSegment.from_wav('../'+df.sort_values('pcnt_speech').iloc[4000]['clip'])
# Out:
#                     <audio controls>
#                         <source src="data:audio/mpeg;base64,..." type="audio/mpeg"/>
#                         Your browser does not support the audio element.
#                     </audio>

# %%
spch_60=df['pcnt_speech']>0.6
df.shape, df[spch_60].shape
# Out:
# ((23461, 22), (22634, 22))

# %%
cos_60 = df['clap_ipa_cos_sim']>0.6
df.shape, df[cos_60].shape
# Out:
# ((23461, 22), (21104, 22))

# %%
df.shape, df[spch_60&cos_60].shape
# Out:
# ((23461, 22), (20478, 22))

# %%
df.to_csv(csv_path)

# %% [markdown]
# # Explore VAD output

# %%
no_vad=df['voice-activity-detection']==''
df[no_vad].head()
# Out:
#         start       end                  transcription  \
# 485   71728.0   74434.0            áɽə́ŋát̪ɔ́ ŋávɛ́
# 490  110836.0  112359.0            àɽə̀ŋàt̪á ŋávɛ̀
# 491  139388.0  141435.0  láɽə̀ŋàt̪à ŋávɛ́ nd̪ɔ̀bà
# 492  142401.0  144732.0  láɽə̀ŋàt̪à ŋávɛ́ nd̪ɔ̀bà
# 493  149963.0  151981.0  láɽə̀ŋàt̪à ŋávɛ́ nd̪ɔ̀bà
#
#                                             eaf_source  \
# 485  /Users/markjos/Library/CloudStorage/GoogleDriv...
# 490  /Users/markjos/Library/CloudStorage/GoogleDriv...
# 491  /Users/markjos/Library/CloudStorage/GoogleDriv...
# 492  /Users/markjos/Library/CloudStorage/GoogleDriv...
# 493  /Users/markjos/Library/CloudStorage/GoogleDriv...
#
#                                             wav_source  \
# 485  /Users/markjos/Library/CloudStorage/GoogleDriv...
# 490  /Users/markjos/Library/CloudStorage/GoogleDriv...
# 491  /Users/markjos/Library/CloudStorage/GoogleDriv...
# 492  /Users/markjos/Library/CloudStorage/GoogleDriv...
# 493  /Users/markjos/Library/CloudStorage/GoogleDriv...
#
#              raw_transcription  \
# 485           áɽə́ŋát̪ɔ́ ŋávɛ́
# 490            àɽə̀ŋàt̪á ŋávɛ̀
# 491  láɽə̀ŋàt̪à ŋávɛ́ nd̪ɔ̀bà
# 492  láɽə̀ŋàt̪à ŋávɛ́ nd̪ɔ̀bà
# 493  láɽə̀ŋàt̪à ŋávɛ́ nd̪ɔ̀bà
#
#                                                   clip  \
# 485  data/tira-asr/clips/HH20220220-1-m01s11ms728-m...
# 490  data/tira-asr/clips/HH20220220-1-m01s50ms836-m...
# 491  data/tira-asr/clips/HH20220220-1-m02s19ms388-m...
# 492  data/tira-asr/clips/HH20220220-1-m02s22ms401-m...
# 493  data/tira-asr/clips/HH20220220-1-m02s29ms963-m...
#
#                                            wav_rawpath  \
# 485  /Users/markjos/Library/CloudStorage/GoogleDriv...
# 490  /Users/markjos/Library/CloudStorage/GoogleDriv...
# 491  /Users/markjos/Library/CloudStorage/GoogleDriv...
# 492  /Users/markjos/Library/CloudStorage/GoogleDriv...
# 493  /Users/markjos/Library/CloudStorage/GoogleDriv...
#
#                                              file_name  \
# 485  data/tira-asr/clips/HH20220220-1-m01s11ms728-m...
# 490  data/tira-asr/clips/HH20220220-1-m01s50ms836-m...
# 491  data/tira-asr/clips/HH20220220-1-m02s19ms388-m...
# 492  data/tira-asr/clips/HH20220220-1-m02s22ms401-m...
# 493  data/tira-asr/clips/HH20220220-1-m02s29ms963-m...
#
#                                          path allosaurus  clap_ipa_cos_sim  \
# 485  HH20220220-1-m01s11ms728-m01s14ms434.wav      a e i          0.272442
# 490  HH20220220-1-m01s50ms836-m01s52ms359.wav                     0.231423
# 491  HH20220220-1-m02s19ms388-m02s21ms435.wav                     0.280254
# 492  HH20220220-1-m02s22ms401-m02s24ms732.wav                     0.290935
# 493  HH20220220-1-m02s29ms963-m02s31ms981.wav          a          0.085982
#
#       wada_snr  nist_stnr speaker-diarization-3.1 voice-activity-detection  \
# 485   2.451369       5.75
# 490  -2.876546       4.75
# 491 -20.000000       4.75
# 492  -5.546748       4.25
# 493  -5.436836       4.00
#
#                     whisper-large-v3  clapipa-transcription-allosaurus
# 485                       Thank you.                            0.1832
# 490                       Thank you.                           -0.1879
# 491                       Thank you.                           -0.1472
# 492   Undertexter av Nicolai Winther                           -0.1472
# 493                            Okay.                            0.2841

# %%
AudioSegment.from_wav('../'+df[no_vad].iloc[74]['clip'])
# Out:
#                     <audio controls>
#                         <source src="data:audio/mpeg;base64,..." type="audio/mpeg"/>
#                         Your browser does not support the audio element.
#                     </audio>

# %%
no_drz=df['speaker-diarization-3.1']==''
df[no_drz].head()
# Out:
#         start       end                  transcription  \
# 485   71728.0   74434.0            áɽə́ŋát̪ɔ́ ŋávɛ́
# 490  110836.0  112359.0            àɽə̀ŋàt̪á ŋávɛ̀
# 491  139388.0  141435.0  láɽə̀ŋàt̪à ŋávɛ́ nd̪ɔ̀bà
# 492  142401.0  144732.0  láɽə̀ŋàt̪à ŋávɛ́ nd̪ɔ̀bà
# 493  149963.0  151981.0  láɽə̀ŋàt̪à ŋávɛ́ nd̪ɔ̀bà
#
#                                             eaf_source  \
# 485  /Users/markjos/Library/CloudStorage/GoogleDriv...
# 490  /Users/markjos/Library/CloudStorage/GoogleDriv...
# 491  /Users/markjos/Library/CloudStorage/GoogleDriv...
# 492  /Users/markjos/Library/CloudStorage/GoogleDriv...
# 493  /Users/markjos/Library/CloudStorage/GoogleDriv...
#
#                                             wav_source  \
# 485  /Users/markjos/Library/CloudStorage/GoogleDriv...
# 490  /Users/markjos/Library/CloudStorage/GoogleDriv...
# 491  /Users/markjos/Library/CloudStorage/GoogleDriv...
# 492  /Users/markjos/Library/CloudStorage/GoogleDriv...
# 493  /Users/markjos/Library/CloudStorage/GoogleDriv...
#
#              raw_transcription  \
# 485           áɽə́ŋát̪ɔ́ ŋávɛ́
# 490            àɽə̀ŋàt̪á ŋávɛ̀
# 491  láɽə̀ŋàt̪à ŋávɛ́ nd̪ɔ̀bà
# 492  láɽə̀ŋàt̪à ŋávɛ́ nd̪ɔ̀bà
# 493  láɽə̀ŋàt̪à ŋávɛ́ nd̪ɔ̀bà
#
#                                                   clip  \
# 485  data/tira-asr/clips/HH20220220-1-m01s11ms728-m...
# 490  data/tira-asr/clips/HH20220220-1-m01s50ms836-m...
# 491  data/tira-asr/clips/HH20220220-1-m02s19ms388-m...
# 492  data/tira-asr/clips/HH20220220-1-m02s22ms401-m...
# 493  data/tira-asr/clips/HH20220220-1-m02s29ms963-m...
#
#                                            wav_rawpath  \
# 485  /Users/markjos/Library/CloudStorage/GoogleDriv...
# 490  /Users/markjos/Library/CloudStorage/GoogleDriv...
# 491  /Users/markjos/Library/CloudStorage/GoogleDriv...
# 492  /Users/markjos/Library/CloudStorage/GoogleDriv...
# 493  /Users/markjos/Library/CloudStorage/GoogleDriv...
#
#                                              file_name  \
# 485  data/tira-asr/clips/HH20220220-1-m01s11ms728-m...
# 490  data/tira-asr/clips/HH20220220-1-m01s50ms836-m...
# 491  data/tira-asr/clips/HH20220220-1-m02s19ms388-m...
# 492  data/tira-asr/clips/HH20220220-1-m02s22ms401-m...
# 493  data/tira-asr/clips/HH20220220-1-m02s29ms963-m...
#
#                                          path allosaurus  clap_ipa_cos_sim  \
# 485  HH20220220-1-m01s11ms728-m01s14ms434.wav      a e i          0.272442
# 490  HH20220220-1-m01s50ms836-m01s52ms359.wav                     0.231423
# 491  HH20220220-1-m02s19ms388-m02s21ms435.wav                     0.280254
# 492  HH20220220-1-m02s22ms401-m02s24ms732.wav                     0.290935
# 493  HH20220220-1-m02s29ms963-m02s31ms981.wav          a          0.085982
#
#       wada_snr  nist_stnr speaker-diarization-3.1 voice-activity-detection  \
# 485   2.451369       5.75
# 490  -2.876546       4.75
# 491 -20.000000       4.75
# 492  -5.546748       4.25
# 493  -5.436836       4.00
#
#                     whisper-large-v3  clapipa-transcription-allosaurus
# 485                       Thank you.                            0.1832
# 490                       Thank you.                           -0.1879
# 491                       Thank you.                           -0.1472
# 492   Undertexter av Nicolai Winther                           -0.1472
# 493                            Okay.                            0.2841

# %%
by_snr=df.sort_values('wada_snr', ascending=True)
by_snr
# Out:
#            start        end                              transcription  \
# 571    1708014.0  1709969.0              ùtìðɔ́ kɔ́cɔ̀ŋù t̪ɔ̀wə̀nǐ
# 8038   1299217.0  1299677.0                              káŋvə́lɛ̂ðà
# 491     139388.0   141435.0              láɽə̀ŋàt̪à ŋávɛ́ nd̪ɔ̀bà
# 9395    700901.0   702381.0                           nɛ̀là nìcə̀lò
# 9394    698771.0   700051.0                            ɛ̀là kìcə̀lò
# ...          ...        ...                                        ...
# 11338   914634.0   916199.0             kàðə́nɔ̀nà lùnɔ̀ t̪àwə̀nì
# 3303   2103840.0  2106160.0  làɾɛ́ ðə́gɔ̀cɔ̀ ŋávɛ́ d̪úd̪ɔ̀ ùnɛ̀ɾɛ̀
# 11339   929501.0   930866.0             kàðə́nɔ̀nà lùnɔ̀ t̪àwə̀nì
# 3305   2140260.0  2141780.0                                  ðə́kɔ̀cɔ̀
# 3209   1247080.0  1249440.0     nɛ́lê návə́lɛ̀ðà ðɛ̀dɔ̀ɽɔ̀ nd̪ɔ̀bà
#
#                                               eaf_source  \
# 571    /Users/markjos/Library/CloudStorage/GoogleDriv...
# 8038   /Users/markjos/Library/CloudStorage/GoogleDriv...
# 491    /Users/markjos/Library/CloudStorage/GoogleDriv...
# 9395   /Users/markjos/Library/CloudStorage/GoogleDriv...
# 9394   /Users/markjos/Library/CloudStorage/GoogleDriv...
# ...                                                  ...
# 11338  /Users/markjos/Library/CloudStorage/GoogleDriv...
# 3303   /Users/markjos/Library/CloudStorage/GoogleDriv...
# 11339  /Users/markjos/Library/CloudStorage/GoogleDriv...
# 3305   /Users/markjos/Library/CloudStorage/GoogleDriv...
# 3209   /Users/markjos/Library/CloudStorage/GoogleDriv...
#
#                                               wav_source  \
# 571    /Users/markjos/Library/CloudStorage/GoogleDriv...
# 8038   /Users/markjos/Library/CloudStorage/GoogleDriv...
# 491    /Users/markjos/Library/CloudStorage/GoogleDriv...
# 9395   /Users/markjos/Library/CloudStorage/GoogleDriv...
# 9394   /Users/markjos/Library/CloudStorage/GoogleDriv...
# ...                                                  ...
# 11338  /Users/markjos/Library/CloudStorage/GoogleDriv...
# 3303   /Users/markjos/Library/CloudStorage/GoogleDriv...
# 11339  /Users/markjos/Library/CloudStorage/GoogleDriv...
# 3305   /Users/markjos/Library/CloudStorage/GoogleDriv...
# 3209   /Users/markjos/Library/CloudStorage/GoogleDriv...
#
#                             raw_transcription  \
# 571            ùʈìðɔ́ kɔ́tʃɔ̀ŋù t̪ɔ̀wə̀nǐ
# 8038                            káŋvə́lɛ̂ðà
# 491                 láɽə̀ŋàt̪à ŋávɛ́ nd̪ɔ̀bà
# 9395                        nɛ̀là nìtʃə̀lò
# 9394                         ɛ̀là kìtʃə̀lò
# ...                                       ...
# 11338          kàðə́nɔ̀nà lùnɔ̀ t̪àwə̀nì
# 3303   làɾɛ́ ðə́ɣɔ̀tʃɔ̀ ŋávɛ́ d̪úd̪ɔ̀ ùnɛ̀ɾɛ̀
# 11339          kàðə́nɔ̀nà lùnɔ̀ t̪àwə̀nì
# 3305                               ðə́kɔ̀tʃɔ̀
# 3209      nɛ́lê návə́lɛ̀ðà ðɛ̀dɔ̀ɽɔ̀ nd̪ɔ̀bà
#
#                                                     clip  \
# 571    data/tira-asr/clips/HH20220220-1-m28s28ms014-m...
# 8038   data/tira-asr/clips/HH20210305-m21s39ms217-m21...
# 491    data/tira-asr/clips/HH20220220-1-m02s19ms388-m...
# 9395   data/tira-asr/clips/HH20220326-2-m11s40ms901-m...
# 9394   data/tira-asr/clips/HH20220326-2-m11s38ms771-m...
# ...                                                  ...
# 11338  data/tira-asr/clips/HH20230510-2-m15s14ms634-m...
# 3303   data/tira-asr/clips/HH20230516-m35s03ms840-m35...
# 11339  data/tira-asr/clips/HH20230510-2-m15s29ms501-m...
# 3305   data/tira-asr/clips/HH20230516-m35s40ms260-m35...
# 3209   data/tira-asr/clips/HH20230516-m20s47ms080-m20...
#
#                                              wav_rawpath  \
# 571    /Users/markjos/Library/CloudStorage/GoogleDriv...
# 8038   /Users/markjos/Library/CloudStorage/GoogleDriv...
# 491    /Users/markjos/Library/CloudStorage/GoogleDriv...
# 9395   /Users/markjos/Library/CloudStorage/GoogleDriv...
# 9394   /Users/markjos/Library/CloudStorage/GoogleDriv...
# ...                                                  ...
# 11338  /Users/markjos/Library/CloudStorage/GoogleDriv...
# 3303   /Users/markjos/Library/CloudStorage/GoogleDriv...
# 11339  /Users/markjos/Library/CloudStorage/GoogleDriv...
# 3305   /Users/markjos/Library/CloudStorage/GoogleDriv...
# 3209   /Users/markjos/Library/CloudStorage/GoogleDriv...
#
#                                                file_name  \
# 571    data/tira-asr/clips/HH20220220-1-m28s28ms014-m...
# 8038   data/tira-asr/clips/HH20210305-m21s39ms217-m21...
# 491    data/tira-asr/clips/HH20220220-1-m02s19ms388-m...
# 9395   data/tira-asr/clips/HH20220326-2-m11s40ms901-m...
# 9394   data/tira-asr/clips/HH20220326-2-m11s38ms771-m...
# ...                                                  ...
# 11338  data/tira-asr/clips/HH20230510-2-m15s14ms634-m...
# 3303   data/tira-asr/clips/HH20230516-m35s03ms840-m35...
# 11339  data/tira-asr/clips/HH20230510-2-m15s29ms501-m...
# 3305   data/tira-asr/clips/HH20230516-m35s40ms260-m35...
# 3209   data/tira-asr/clips/HH20230516-m20s47ms080-m20...
#
#                                            path  \
# 571    HH20220220-1-m28s28ms014-m28s29ms969.wav
# 8038     HH20210305-m21s39ms217-m21s39ms677.wav
# 491    HH20220220-1-m02s19ms388-m02s21ms435.wav
# 9395   HH20220326-2-m11s40ms901-m11s42ms381.wav
# 9394   HH20220326-2-m11s38ms771-m11s40ms051.wav
# ...                                         ...
# 11338  HH20230510-2-m15s14ms634-m15s16ms199.wav
# 3303     HH20230516-m35s03ms840-m35s06ms160.wav
# 11339  HH20230510-2-m15s29ms501-m15s30ms866.wav
# 3305     HH20230516-m35s40ms260-m35s41ms780.wav
# 3209     HH20230516-m20s47ms080-m20s49ms440.wav
#
#                                             allosaurus  clap_ipa_cos_sim  \
# 571                                      a ə a ʂ a ʂ ɔ          0.194071
# 8038                                            e t̪ a          0.448350
# 491                                                             0.280254
# 9395                              n ɛ l a d e d̪ u l u          0.755806
# 9394                             e ð e l a k i k e l o          0.729497
# ...                                                ...               ...
# 11338                p a l n a n a l u n a k o w a n e          0.742630
# 3303       l a r a ð e v o i o n a ð e ð e ð o n a ð e          0.678819
# 11339                  k a l o n o n e l u n a t o n e          0.719478
# 3305                                   j a n e k ə ʂ o          0.482868
# 3209   m e l e n a v e l e v a ð ə d o ŋ l o n t o v a          0.693258
#
#        wada_snr  nist_stnr                         speaker-diarization-3.1  \
# 571       -20.0       3.50
# 8038      -20.0       2.25                          0.031 0.520 SPEAKER_00
# 491       -20.0       4.75
# 9395      -20.0       4.75                          0.031 1.516 SPEAKER_00
# 9394      -20.0       5.00                          0.031 1.364 SPEAKER_00
# ...         ...        ...                                             ...
# 11338     100.0      70.50                          0.031 1.381 SPEAKER_00
# 3303      100.0      69.75                          0.166 2.225 SPEAKER_00
# 11339     100.0      69.00                          0.031 1.330 SPEAKER_00
# 3305      100.0      70.50  0.031 0.048 SPEAKER_00; 0.132 1.583 SPEAKER_00
# 3209      100.0      75.50                          0.166 2.123 SPEAKER_00
#
#       voice-activity-detection  \
# 571
# 8038        0.031 0.487 SPEECH
# 491
# 9395        0.115 1.499 SPEECH
# 9394        0.115 1.263 SPEECH
# ...                        ...
# 11338       0.149 1.364 SPEECH
# 3303        0.250 2.123 SPEECH
# 11339       0.098 1.280 SPEECH
# 3305        0.267 1.533 SPEECH
# 3209        0.250 2.140 SPEECH
#
#                                      whisper-large-v3  \
# 571                                             Okay.
# 8038                                  Eu vou ler, né?
# 491                                        Thank you.
# 9395                                   Néla, Nechelo,
# 9394                                     Ela kichilu.
# ...                                               ...
# 11338                     Fadhana narluna, otkawalni.
# 3303                    லாராது கொஞ்சம் அவைது தொன்னாரே
# 11339                      Kuadon on ollut notto-one.
# 3305                                          Y aquí.
# 3209    Nearly novel-y though, the doll and the wall.
#
#        clapipa-transcription-allosaurus
# 571                              0.1315
# 8038                             0.0669
# 491                             -0.1472
# 9395                             0.6743
# 9394                             0.8640
# ...                                 ...
# 11338                            0.7202
# 3303                             0.7219
# 11339                            0.8797
# 3305                             0.2263
# 3209                             0.8775
#
# [23461 rows x 18 columns]

# %%
AudioSegment.from_wav('../'+by_snr.iloc[20000]['clip'])
# Out:
#                     <audio controls>
#                         <source src="data:audio/mpeg;base64,..." type="audio/mpeg"/>
#                         Your browser does not support the audio element.
#                     </audio>
