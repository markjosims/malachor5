# %%
import pandas as pd

# %%
tira_verb_xlsx = r'C:\projects\malachor5\meta\tira_verbs_conjugated.xlsx'

# %%
df = pd.read_excel(tira_verb_xlsx)
df
# Out:
#     Tira orthography (imperative andative)  \
# 0                                      NaN
# 1                                     mezo
# 2                                     ero
# 3                                     ero
# 4                                     ero
# ..                                     ...
# 357                                    NaN
# 358                                    NaN
# 359                                    NaN
# 360                                    NaN
# 361                                    NaN
#
#     Tira orthography (imperative ventive: towards or far away)  \
# 0                                                  NaN
# 1                                                 meza
# 2                                                  era
# 3                                                  era
# 4                                                  era
# ..                                                 ...
# ...

# %% [markdown]
# Only keep rows from TAMD dataset

# %%
df['Part of TAMD dataset?'].value_counts()
# Out:
# Part of TAMD dataset?
# yes                                               102
# yes (extended)                                     37
# yes (extended, to be elicited)                     20
# maybe                                              16
# yes (has extension suffix)                          7
# Duplicate?                                          5
# needs revisiting                                    4
# Duplicate? (compare with 'say + direct quote')      2
# Duplicate (= 'plait or make rope')                  1
# Duplicate? (compare with 'touch')                   1
# Duplicate? (compare with 'stop')                    1
# Duplicate? (compare with 'trough holds water')      1
# recheck FV variation                                1
# Name: count, dtype: int64
